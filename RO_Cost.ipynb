# %%
import Data_Conversion
import Input_Parameters 
import Data_Conversion
import Passive_Model
import Solar_Generation
import Electrical_Load
import RO
# Out:
# /Users/jimmy/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
import numpy as np
import pandas as pd

# %%
# Sensitivity Analysis on Loss of Load Cost, Stochastic Optimization
# Fred Fan, Stanford University, 03/17/2025

# %%
# Define the base data directory, list of loss of load costs, and the weather year.
data_dir = "Data"

location = "HalfMoonBay"

# Example loss of load cost sensitivity
lol_costs = [
             10, 
             100, 
             1000
             ] # $/kWh 

# 20 years of training data
weather_year_list_training = list(range(1998, 2018))  # use list(range(1998, 2018)) for full dataset
# 5 years of training data
weather_year_list_testing = list(range(2018, 2023))  # use list(range(2018, 2023)) for full dataset

# Set a random seed for consistency

total_cells = len(weather_year_list_training) + len(weather_year_list_testing) 

sequential_numbers = np.arange(1, total_cells + 1)

# Reshape the array into a 2D array with i rows and j columns
data = sequential_numbers.reshape(1, total_cells)

# Convert the array into a DataFrame
random_seeds = pd.DataFrame(data, columns=[f'Column_{k+1}' for k in range(total_cells)])

lat, lon, timezone = Data_Conversion.get_timezone_singlezone(data_dir, location)

print(random_seeds)
# Out:
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_1998.csv
#    Column_1  Column_2  Column_3  Column_4  Column_5  Column_6  Column_7  \
# 0         1         2         3         4         5         6         7
#
#    Column_8  Column_9  Column_10  ...  Column_16  Column_17  Column_18  \
# 0         8         9         10  ...         16         17         18
#
#    Column_19  Column_20  Column_21  Column_22  Column_23  Column_24  Column_25
# 0         19         20         21         22         23         24         25
#
# [1 rows x 25 columns]

# %%
# Create the dictionary
training_results = {}

# %%
# Sensitivity Analysis on Loss of Load Cost

# Initialize storing space to store all input_dfs
input_df_list_train = []

# First, collect all training data
for j in range(len(weather_year_list_training)):
    year = weather_year_list_training[j]

    # Get a unique random seed number
    random_seed = random_seeds.iloc[0, j]
    print(random_seed)
    
    # Read NSRDB weather data of the given location of the given year
    NSRDB_raw_weather = Data_Conversion.read_NSRDB(data_dir, location, year)

    # Prepare weather data file using NSRDB data
    weather_data = Data_Conversion.prepare_NSRDB(NSRDB_raw_weather, lat, lon, timezone)

    # Prepare heating and cooling load using weather data and passive model
    NetHeatTransfers = Passive_Model.passive_model(Input_Parameters.calibration_file_path, weather_data, Input_Parameters.T_indoor_constant, lat)

    # Prepare solar PV capacity factor using weather data
    pv_cf = Solar_Generation.generate_pv(weather_data, lat)

    # Prepare occupancy and electrical load schedule using for a specific random seed number for a specific year at a specific location
    load_sched = Electrical_Load.generate_schedules("bayes", weather_data, random_seed)
    
    # Combine all relative input data as input_df, which will be the input of the capacity optimization algorithm
    input_df = Data_Conversion.combine_input_NSRDB(weather_data, load_sched, pv_cf, NetHeatTransfers)

    # Add input_df to list
    input_df_list_train.append(input_df)

# Now that we have all training data, run sensitivity analysis
training_results = {}  # Initialize results dictionary
for i in range(len(lol_costs)):
    lolc = lol_costs[i]
    print(f"Running optimization with loss of load cost: {lolc}")
    
    PV_Size, Battery_Size, PCM_Heating_Size, PCM_Cooling_Size, ObjValue, First_stage_cost, Second_stage_cost = RO.RO_training(input_df_list_train, lolc)

    # Store the variables in the nested dictionary
    training_results[lolc] = {
        'PV_Size': PV_Size,
        'Battery_Size': Battery_Size,
        'PCM_Heating_Size': PCM_Heating_Size,
        'PCM_Cooling_Size': PCM_Cooling_Size,
        'Total Cost': ObjValue,
        'Capital Cost': First_stage_cost,
        'Operation Cost': Second_stage_cost
    }
# Out:
# 1
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_1998.csv
# 2
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_1999.csv
# 3
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2000.csv
# 4
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2001.csv
# 5
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2002.csv
# 6
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2003.csv
# 7
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2004.csv
# 8
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2005.csv
# 9
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2006.csv
# 10
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2007.csv
# 11
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2008.csv
# 12
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2009.csv
# 13
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2010.csv
# 14
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2011.csv
# 15
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2012.csv
# 16
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2013.csv
# 17
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2014.csv
# 18
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2015.csv
# 19
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2016.csv
# 20
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2017.csv
# Running optimization with loss of load cost: 10
# Starting robust optimization algorithm...
#
# --- Iteration 1 ---
# Adding cut for scenario 11 with cost 144.94
# Current solution:
#   PV Size: 10.39 kW
#   Battery Size: 1.34 kWh
#   PCM Heating Size: 44.08 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 391.74
#   First-stage cost: 21160.63
#   Total cost: 20409.43
#   Lower Bound: 20409.43, Upper Bound: 21305.57
#   Optimality gap: 4.21%
#   Maximum capacity change: 39.082401
#
# --- Iteration 2 ---
# Adding cut for scenario 16 with cost 534.95
# Current solution:
#   PV Size: 10.34 kW
#   Battery Size: 1.75 kWh
#   PCM Heating Size: 42.68 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 393.09
#   First-stage cost: 20017.69
#   Total cost: 20415.96
#   Lower Bound: 20415.96, Upper Bound: 20552.64
#   Optimality gap: 0.67%
#   Maximum capacity change: 1.401763
#
# --- Iteration 3 ---
# Adding cut for scenario 0 with cost 461.13
# Current solution:
#   PV Size: 9.70 kW
#   Battery Size: 1.37 kWh
#   PCM Heating Size: 43.16 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 524.48
#   First-stage cost: 20022.86
#   Total cost: 20467.73
#   Lower Bound: 20467.73, Upper Bound: 20483.99
#   Optimality gap: 0.08%
#   Maximum capacity change: 0.646286
#
# --- Iteration 4 ---
# Adding cut for scenario 17 with cost 536.82
# Current solution:
#   PV Size: 9.76 kW
#   Battery Size: 1.41 kWh
#   PCM Heating Size: 43.03 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 519.57
#   First-stage cost: 19943.25
#   Total cost: 20468.22
#   Lower Bound: 20468.22, Upper Bound: 20480.07
#   Optimality gap: 0.06%
#   Maximum capacity change: 0.124371
#
# --- Iteration 5 ---
# Current solution:
#   PV Size: 9.76 kW
#   Battery Size: 1.41 kWh
#   PCM Heating Size: 43.03 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 519.57
#   First-stage cost: 19948.65
#   Total cost: 20468.22
#   Lower Bound: 20468.22, Upper Bound: 20468.22
#   Optimality gap: -0.00%
#
# Algorithm converged based on optimality gap!
# Running optimization with loss of load cost: 100
# Starting robust optimization algorithm...
#
# --- Iteration 1 ---
# Adding cut for scenario 11 with cost 1449.40
# Current solution:
#   PV Size: 11.93 kW
#   Battery Size: 2.27 kWh
#   PCM Heating Size: 71.75 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 21160.63
#   Total cost: 20962.88
#   Lower Bound: 20962.88, Upper Bound: 22610.03
#   Optimality gap: 7.29%
#   Maximum capacity change: 66.751870
#
# --- Iteration 2 ---
# Adding cut for scenario 16 with cost 2566.52
# Current solution:
#   PV Size: 13.52 kW
#   Battery Size: 4.37 kWh
#   PCM Heating Size: 47.01 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 368.78
#   First-stage cost: 20962.88
#   Total cost: 21039.26
#   Lower Bound: 21039.26, Upper Bound: 22610.03
#   Optimality gap: 6.95%
#   Maximum capacity change: 24.743847
#
# --- Iteration 3 ---
# Adding cut for scenario 0 with cost 1271.74
# Current solution:
#   PV Size: 12.59 kW
#   Battery Size: 5.24 kWh
#   PCM Heating Size: 54.86 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 154.48
#   First-stage cost: 20670.49
#   Total cost: 21055.66
#   Lower Bound: 21055.66, Upper Bound: 21942.22
#   Optimality gap: 4.04%
#   Maximum capacity change: 7.851328
#
# --- Iteration 4 ---
# Adding cut for scenario 10 with cost 495.60
# Current solution:
#   PV Size: 11.35 kW
#   Battery Size: 3.93 kWh
#   PCM Heating Size: 59.34 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 553.41
#   First-stage cost: 20901.18
#   Total cost: 21330.89
#   Lower Bound: 21330.89, Upper Bound: 21396.78
#   Optimality gap: 0.31%
#   Maximum capacity change: 4.484551
#
# --- Iteration 5 ---
# Current solution:
#   PV Size: 11.35 kW
#   Battery Size: 3.93 kWh
#   PCM Heating Size: 59.34 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 553.41
#   First-stage cost: 20777.47
#   Total cost: 21330.89
#   Lower Bound: 21330.89, Upper Bound: 21330.89
#   Optimality gap: 0.00%
#
# Algorithm converged based on optimality gap!
# Running optimization with loss of load cost: 1000
# Starting robust optimization algorithm...
#
# --- Iteration 1 ---
# Adding cut for scenario 11 with cost 14494.00
# Current solution:
#   PV Size: 11.93 kW
#   Battery Size: 2.27 kWh
#   PCM Heating Size: 71.75 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 21160.63
#   Total cost: 20962.88
#   Lower Bound: 20962.88, Upper Bound: 35654.63
#   Optimality gap: 41.21%
#   Maximum capacity change: 66.751870
#
# --- Iteration 2 ---
# Adding cut for scenario 16 with cost 25665.23
# Current solution:
#   PV Size: 11.92 kW
#   Battery Size: 6.80 kWh
#   PCM Heating Size: 57.63 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 20962.88
#   Total cost: 21094.56
#   Lower Bound: 21094.56, Upper Bound: 35654.63
#   Optimality gap: 40.84%
#   Maximum capacity change: 14.123103
#
# --- Iteration 3 ---
# Adding cut for scenario 10 with cost 3424.25
# Current solution:
#   PV Size: 10.43 kW
#   Battery Size: 6.80 kWh
#   PCM Heating Size: 74.61 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 21094.56
#   Total cost: 21423.65
#   Lower Bound: 21423.65, Upper Bound: 24518.81
#   Optimality gap: 12.62%
#   Maximum capacity change: 16.984118
#
# --- Iteration 4 ---
# Adding cut for scenario 6 with cost 3490.38
# Current solution:
#   PV Size: 13.87 kW
#   Battery Size: 6.80 kWh
#   PCM Heating Size: 67.05 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 21423.65
#   Total cost: 21491.34
#   Lower Bound: 21491.34, Upper Bound: 24518.81
#   Optimality gap: 12.35%
#   Maximum capacity change: 7.566424
#
# --- Iteration 5 ---
# Adding cut for scenario 1 with cost 63.99
# Current solution:
#   PV Size: 14.40 kW
#   Battery Size: 6.80 kWh
#   PCM Heating Size: 65.87 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 21491.34
#   Total cost: 21501.86
#   Lower Bound: 21501.86, Upper Bound: 21555.33
#   Optimality gap: 0.25%
#   Maximum capacity change: 1.175462
#
# --- Iteration 6 ---
# Adding cut for scenario 0 with cost 0.00
# Current solution:
#   PV Size: 14.40 kW
#   Battery Size: 6.80 kWh
#   PCM Heating Size: 65.87 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 21501.86
#   Total cost: 21501.86
#   Lower Bound: 21501.86, Upper Bound: 21501.86
#   Optimality gap: 0.00%
#
# Algorithm converged based on optimality gap!

# %%
print(training_results)
# Out:
# {10: {'PV_Size': 9.757, 'Battery_Size': 1.407, 'PCM_Heating_Size': 43.034, 'PCM_Cooling_Size': 0.0, 'Total Cost': 20468.287, 'Capital Cost': 19948.714, 'Operation Cost': 519.573}, 100: {'PV_Size': 11.352, 'Battery_Size': 3.927, 'PCM_Heating_Size': 59.344, 'PCM_Cooling_Size': 0.0, 'Total Cost': 21330.894, 'Capital Cost': 20777.48, 'Operation Cost': 553.414}, 1000: {'PV_Size': 14.404, 'Battery_Size': 6.8, 'PCM_Heating_Size': 65.871, 'PCM_Cooling_Size': 0.0, 'Total Cost': 21501.842, 'Capital Cost': 21501.842, 'Operation Cost': 0.0}}

# %%
# Testing:

# Create the nested dictionary
testing_results = {lolc: {year: {} for year in weather_year_list_testing} for lolc in lol_costs}

for j in range(len(weather_year_list_testing)):
    
    year = weather_year_list_testing[j]
    
    # Get a unique random seed number
    random_seed = random_seeds.iloc[0, j+len(weather_year_list_training)]
    print(random_seed)
    
    # Read NSRDB weather data of the given location of the given year
    NSRDB_raw_weather = Data_Conversion.read_NSRDB(data_dir, location, year)

    # Prepare weather data file using NSRDB data
    weather_data = Data_Conversion.prepare_NSRDB(NSRDB_raw_weather, lat, lon, timezone)

    # Prepare heating and cooling load using weather data and passive model
    NetHeatTransfers = Passive_Model.passive_model(Input_Parameters.calibration_file_path, weather_data, Input_Parameters.T_indoor_constant, lat)

    # Prepare solar PV capacity factor using weather data
    pv_cf = Solar_Generation.generate_pv(weather_data, lat)

    # Prepare occupancy and electrical load schedule using for a specific random seed number for a specific year at a specific location
    load_sched = Electrical_Load.generate_schedules("bayes", weather_data, random_seed)
    
    # Combine all relative input data as input_df, which will be the input of the capacity optimization algorithm
    input_df = Data_Conversion.combine_input_NSRDB(weather_data, load_sched, pv_cf, NetHeatTransfers)
    
    for i in range(len(lol_costs)):
        
        lolc = lol_costs[i]
        
        test_capacities = [training_results[lolc]['PV_Size'], training_results[lolc]['Battery_Size'], training_results[lolc]['PCM_Heating_Size'], training_results[lolc]['PCM_Cooling_Size']]
        
        ObjValue, First_stage_cost, Second_stage_cost = RO.simulate(input_df, lolc, test_capacities)
        # Store the variables in the nested dictionary
        testing_results[lolc][year] = {
            'Total Cost': ObjValue,
            'Capital Cost': First_stage_cost,
            'Operation Cost': Second_stage_cost
        }
# Out:
# 21
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2018.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpa8de0_bu.pyomo.lp
# Reading time = 0.31 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xe2a96078
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-04, 4e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96207 rows and 55661 columns
# Presolve time: 0.26s
# Presolved: 61476 rows, 84499 columns, 198224 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.352e+05
#  Factor NZ  : 6.546e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.252e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.06237331e+06 -8.11475649e+05  6.86e+01 0.00e+00  2.72e+01     0s
#    1   4.09912314e+05 -3.11905527e+05  2.08e+01 3.90e-02  7.15e+00     0s
#    2   5.41173623e+04 -5.51072120e+04  2.34e+00 2.66e-15  9.12e-01     1s
#    3   1.28729152e+04 -1.92541118e+04  5.30e-01 2.66e-15  2.46e-01     1s
#
# Barrier performed 3 iterations in 0.63 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 22018 iterations and 0.63 seconds (0.44 work units)
# Optimal objective  8.523926510e+01
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp0i38coe4.pyomo.lp
# Reading time = 0.30 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x522fcd9e
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-04, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96207 rows and 55661 columns
# Presolve time: 0.19s
# Presolved: 61476 rows, 84499 columns, 198224 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.352e+05
#  Factor NZ  : 6.546e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.252e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.10438695e+07 -9.13703185e+06  7.31e+01 0.00e+00  2.87e+02     0s
#    1   4.20082522e+06 -2.73919593e+06  2.22e+01 2.13e-14  6.77e+01     0s
#    2   3.74024248e+05 -5.21536102e+05  2.01e+00 3.55e-14  7.25e+00     0s
#    3   7.74879093e+04 -1.24960003e+05  4.15e-01 1.60e-14  1.51e+00     1s
#
# Barrier performed 3 iterations in 0.53 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 21038 iterations and 0.54 seconds (0.42 work units)
# Optimal objective  0.000000000e+00
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpt0oc2adp.pyomo.lp
# Reading time = 0.32 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x50efb9c7
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-04, 7e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 95064 rows and 55661 columns
# Presolve time: 0.20s
# Presolved: 62619 rows, 84499 columns, 200510 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.397e+05
#  Factor NZ  : 6.506e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.958e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.13008458e+08 -9.50367237e+07  7.72e+01 0.00e+00  2.95e+03     0s
#    1   4.42038858e+07 -2.95751584e+07  2.49e+01 1.71e-13  7.05e+02     0s
#    2   3.02650870e+06 -5.72808410e+06  1.77e+00 4.26e-13  6.82e+01     0s
#
# Barrier performed 2 iterations in 0.47 seconds (0.30 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20065 iterations and 0.47 seconds (0.43 work units)
# Optimal objective  0.000000000e+00
# 22
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2019.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmphku4il41.pyomo.lp
# Reading time = 0.30 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x95006dc6
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-04, 4e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96224 rows and 55662 columns
# Presolve time: 0.23s
# Presolved: 61459 rows, 84498 columns, 198168 nonzeros
#
# Ordering time: 0.02s
#
# Barrier statistics:
#  AA' NZ     : 1.351e+05
#  Factor NZ  : 6.556e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.278e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.05818870e+06 -8.12151836e+05  6.81e+01 0.00e+00  2.71e+01     0s
#    1   4.03783176e+05 -3.09488927e+05  2.02e+01 3.95e-02  7.04e+00     0s
#    2   6.32933981e+04 -4.81371416e+04  2.79e+00 3.11e-15  9.50e-01     0s
#    3   1.80804216e+04 -1.99846801e+04  7.66e-01 2.22e-15  2.98e-01     1s
#    4   8.83744067e+03 -1.04968291e+04  3.96e-01 1.78e-15  1.47e-01     1s
#
# Barrier performed 4 iterations in 0.62 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 22902 iterations and 0.63 seconds (0.45 work units)
# Optimal objective  3.257823651e+02
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpqtmta9c_.pyomo.lp
# Reading time = 0.29 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x49d15205
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-04, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96224 rows and 55662 columns
# Presolve time: 0.19s
# Presolved: 61459 rows, 84498 columns, 198168 nonzeros
#
# Ordering time: 0.02s
#
# Barrier statistics:
#  AA' NZ     : 1.351e+05
#  Factor NZ  : 6.556e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.278e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.10176526e+07 -9.14356235e+06  7.27e+01 0.00e+00  2.86e+02     0s
#    1   4.17687913e+06 -2.71912070e+06  2.19e+01 2.13e-14  6.73e+01     0s
#    2   5.40119248e+05 -5.34853462e+05  2.69e+00 3.55e-14  8.86e+00     0s
#    3   1.07297366e+05 -1.55863252e+05  5.31e-01 2.13e-14  1.99e+00     1s
#
# Barrier performed 3 iterations in 0.55 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 21324 iterations and 0.55 seconds (0.43 work units)
# Optimal objective  3.465354718e+01
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpqm_s3_tx.pyomo.lp
# Reading time = 0.29 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x5e5b85aa
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-04, 7e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 95131 rows and 55662 columns
# Presolve time: 0.20s
# Presolved: 62552 rows, 84498 columns, 200354 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.394e+05
#  Factor NZ  : 6.572e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.119e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.12931702e+08 -9.51475755e+07  7.69e+01 0.00e+00  2.95e+03     0s
#    1   4.42945606e+07 -2.93377794e+07  2.48e+01 1.71e-13  7.04e+02     0s
#    2   4.37122370e+06 -5.78536475e+06  2.47e+00 3.13e-13  8.09e+01     0s
#    3   5.23081338e+05 -1.31276054e+06  2.94e-01 1.71e-13  1.33e+01     0s
#    4   3.41540165e+03 -8.18000904e+04  1.16e-03 1.71e-13  5.98e-01     1s
#
# Barrier performed 4 iterations in 0.56 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20304 iterations and 0.56 seconds (0.44 work units)
# Optimal objective  0.000000000e+00
# 23
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2020.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpxkvtvhxu.pyomo.lp
# Reading time = 0.32 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x220c9924
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-04, 4e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96203 rows and 55665 columns
# Presolve time: 0.22s
# Presolved: 61480 rows, 84495 columns, 198240 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.352e+05
#  Factor NZ  : 6.545e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.247e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.05896221e+06 -8.11215763e+05  6.83e+01 0.00e+00  2.71e+01     0s
#    1   4.01628733e+05 -3.11881022e+05  2.02e+01 3.92e-02  7.03e+00     0s
#    2   5.00739736e+04 -5.51342831e+04  2.15e+00 2.66e-15  8.71e-01     0s
#    3   1.13192503e+04 -1.96817447e+04  4.58e-01 3.11e-15  2.36e-01     1s
#
# Barrier performed 3 iterations in 0.58 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 21380 iterations and 0.60 seconds (0.42 work units)
# Optimal objective  9.732284559e+01
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp5sezn12h.pyomo.lp
# Reading time = 0.30 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x280b0c7a
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-04, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96203 rows and 55665 columns
# Presolve time: 0.21s
# Presolved: 61480 rows, 84495 columns, 198240 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.352e+05
#  Factor NZ  : 6.545e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.247e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.10292098e+07 -9.13325703e+06  7.30e+01 0.00e+00  2.86e+02     0s
#    1   4.13193189e+06 -2.75145444e+06  2.17e+01 2.13e-14  6.69e+01     0s
#    2   4.03058855e+05 -5.50973473e+05  1.99e+00 3.91e-14  7.66e+00     0s
#    3   7.01748574e+04 -1.25307730e+05  3.47e-01 1.42e-14  1.45e+00     0s
#
# Barrier performed 3 iterations in 0.50 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20562 iterations and 0.50 seconds (0.41 work units)
# Optimal objective  3.645978728e+01
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpeto3r71b.pyomo.lp
# Reading time = 0.30 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x5ea6ac3b
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-04, 7e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 95015 rows and 55665 columns
# Presolve time: 0.21s
# Presolved: 62668 rows, 84495 columns, 200616 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.400e+05
#  Factor NZ  : 6.497e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.934e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.13038269e+08 -9.49653120e+07  7.73e+01 0.00e+00  2.95e+03     0s
#    1   4.40819981e+07 -2.97500906e+07  2.49e+01 1.71e-13  7.04e+02     0s
#    2   2.88750561e+06 -5.78934851e+06  1.71e+00 4.55e-13  6.73e+01     0s
#    3   1.44899770e+05 -8.57285287e+05  8.83e-02 2.27e-13  7.12e+00     1s
#
# Barrier performed 3 iterations in 0.61 seconds (0.34 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 19274 iterations and 0.61 seconds (0.42 work units)
# Optimal objective  0.000000000e+00
# 24
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2021.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpmuq638k_.pyomo.lp
# Reading time = 0.30 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x39692327
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-06, 4e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96203 rows and 55653 columns
# Presolve time: 0.19s
# Presolved: 61480 rows, 84507 columns, 198232 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.352e+05
#  Factor NZ  : 6.548e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.255e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.05523403e+06 -8.10417457e+05  6.81e+01 0.00e+00  2.70e+01     0s
#    1   4.01020685e+05 -3.12524872e+05  2.02e+01 4.04e-02  7.03e+00     0s
#    2   5.07520571e+04 -5.34422988e+04  2.17e+00 3.11e-15  8.64e-01     0s
#    3   1.21332462e+04 -1.90233075e+04  4.98e-01 2.22e-15  2.38e-01     0s
#    4   6.98856858e+03 -7.09353000e+03  3.08e-01 1.78e-15  1.05e-01     1s
#
# Barrier performed 4 iterations in 0.56 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 22142 iterations and 0.57 seconds (0.51 work units)
# Optimal objective  8.160447732e+01
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpmnzac0pc.pyomo.lp
# Reading time = 0.34 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xf8316111
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-06, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96203 rows and 55653 columns
# Presolve time: 0.19s
# Presolved: 61480 rows, 84507 columns, 198232 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.352e+05
#  Factor NZ  : 6.548e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.255e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.09671000e+07 -9.12307098e+06  7.25e+01 0.00e+00  2.85e+02     0s
#    1   4.15818216e+06 -2.73932908e+06  2.19e+01 2.13e-14  6.72e+01     0s
#    2   3.96651174e+05 -5.28531450e+05  2.14e+00 4.62e-14  7.51e+00     0s
#    3   4.54362936e+04 -1.09104853e+05  2.41e-01 2.13e-14  1.13e+00     1s
#
# Barrier performed 3 iterations in 0.50 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20914 iterations and 0.51 seconds (0.50 work units)
# Optimal objective  0.000000000e+00
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp82ryui02.pyomo.lp
# Reading time = 0.30 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xd99458a4
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-06, 7e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 94998 rows and 55653 columns
# Presolve time: 0.21s
# Presolved: 62685 rows, 84507 columns, 200642 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.400e+05
#  Factor NZ  : 6.517e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.973e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.12395609e+08 -9.48432863e+07  7.68e+01 0.00e+00  2.93e+03     0s
#    1   4.38644621e+07 -2.95985101e+07  2.47e+01 1.71e-13  7.00e+02     0s
#    2   3.34996979e+06 -5.79081832e+06  1.97e+00 3.41e-13  7.15e+01     0s
#    3   2.44204720e+05 -1.03128318e+06  1.46e-01 2.27e-13  9.12e+00     1s
#
# Barrier performed 3 iterations in 0.50 seconds (0.34 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Solved in 23722 iterations and 0.50 seconds (0.60 work units)
# Optimal objective  0.000000000e+00
# 25
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2022.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp50rl0q5u.pyomo.lp
# Reading time = 0.29 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xd35d91c6
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-04, 4e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96219 rows and 55661 columns
# Presolve time: 0.19s
# Presolved: 61464 rows, 84499 columns, 198184 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.351e+05
#  Factor NZ  : 6.548e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.258e+06 (less than 1 second per iteration)
#  Threads    : 9
#
# Barrier performed 0 iterations in 0.56 seconds (0.25 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 21741 iterations and 0.56 seconds (0.42 work units)
# Optimal objective  2.411279923e+02
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp8dnnnb_s.pyomo.lp
# Reading time = 0.29 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xe80de9e0
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-04, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96219 rows and 55661 columns
# Presolve time: 0.20s
# Presolved: 61464 rows, 84499 columns, 198184 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.351e+05
#  Factor NZ  : 6.548e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.258e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.09514468e+07 -9.11451141e+06  7.24e+01 0.00e+00  2.85e+02     0s
#    1   4.16145367e+06 -2.74593062e+06  2.20e+01 2.13e-14  6.72e+01     0s
#    2   3.54764553e+05 -5.32486117e+05  1.92e+00 3.20e-14  7.13e+00     0s
#    3   8.95248808e+04 -9.37232426e+04  4.79e-01 2.13e-14  1.37e+00     0s
#
# Barrier performed 3 iterations in 0.50 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20798 iterations and 0.53 seconds (0.43 work units)
# Optimal objective  5.844463764e+02
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpvazzv0ni.pyomo.lp
# Reading time = 0.29 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x2aa3e9a0
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-04, 7e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 94827 rows and 55661 columns
# Presolve time: 0.19s
# Presolved: 62856 rows, 84499 columns, 200968 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.407e+05
#  Factor NZ  : 6.483e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.864e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.12053435e+08 -9.46027033e+07  7.67e+01 0.00e+00  2.92e+03     0s
#    1   4.37969692e+07 -2.97057145e+07  2.48e+01 2.27e-13  6.99e+02     0s
#    2   3.28345263e+06 -5.86329744e+06  1.93e+00 3.41e-13  7.12e+01     0s
#
# Barrier performed 2 iterations in 0.49 seconds (0.30 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 19850 iterations and 0.50 seconds (0.43 work units)
# Optimal objective  0.000000000e+00

# %%
# Initialize a dictionary to store averaged results
testing_averaged_results = {}

# Iterate over each loss of load cost
for lolc, years_data in testing_results.items():
    # Initialize a dictionary to store sums and counts for averaging
    sums = {
        'Total Cost': 0,
        'Capital Cost': 0,
        'Operation Cost': 0
    }
    count = 0

    # Iterate over each year for the loss of load cost
    for year, data in years_data.items():
        for key in sums:
            sums[key] += data[key]
        count += 1

    # Calculate averages
    testing_averaged_results[lolc] = {key: value / count for key, value in sums.items()}

# Print the averaged results
print(testing_averaged_results)
# Out:
# {10: {'Total Cost': 20114.9298, 'Capital Cost': 19948.714, 'Operation Cost': 166.2152}, 100: {'Total Cost': 20908.5922, 'Capital Cost': 20777.48, 'Operation Cost': 131.11200000000002}, 1000: {'Total Cost': 21501.842, 'Capital Cost': 21501.842, 'Operation Cost': 0.0}}

# %%
from pathlib import Path

# Define the output file path
output_file = "Results_SA_LoLC_RO.xlsx"

# Store Training Result
train_df = pd.DataFrame(training_results).T 
sheet_name_train = "Training Results"

# Check if the file exists
if not Path(output_file).exists():
    # If the file does not exist, create it
    with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
        train_df.to_excel(writer, sheet_name=sheet_name_train)
    print(f"File '{output_file}' created with sheet '{sheet_name_train}'.")
else:
    # If the file exists, append the new sheet
    with pd.ExcelWriter(output_file, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
        train_df.to_excel(writer, sheet_name=sheet_name_train)
    print(f"Data written to '{output_file}' in sheet '{sheet_name_train}'.")


# Store Testing Result
test_df = pd.DataFrame(testing_averaged_results).T 
sheet_name_test = "Testing Results"

# Check if the file exists
if not Path(output_file).exists():
    # If the file does not exist, create it
    with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
        test_df.to_excel(writer, sheet_name=sheet_name_test)
    print(f"File '{output_file}' created with sheet '{sheet_name_test}'.")
else:
    # If the file exists, append the new sheet
    with pd.ExcelWriter(output_file, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
        test_df.to_excel(writer, sheet_name=sheet_name_test)
    print(f"Data written to '{output_file}' in sheet '{sheet_name_test}'.")
# Out:
# File 'Results_SA_LoLC_RO.xlsx' created with sheet 'Training Results'.
# Data written to 'Results_SA_LoLC_RO.xlsx' in sheet 'Testing Results'.
