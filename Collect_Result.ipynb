# %%
import os
import re
import pandas as pd
import numpy as np
import openpyxl

# %%
def load_data(folder_path, pattern_prefix):
    """
    Load data from Excel files with flexible naming pattern
    
    Args:
        folder_path: Path to directory containing Excel files
        pattern_prefix: The middle part of the filename (e.g., "Location" or "Scenarios")
                       Files should be named like f"SA_{pattern_prefix}_*.xlsx"
    
    Returns:
        Nested dictionary: {name: {sheet: DataFrame}}
    """
    # Verify the folder exists
    if not os.path.exists(folder_path):
        raise FileNotFoundError(f"The directory {folder_path} does not exist")
    
    # Create regex pattern to extract names
    pattern = re.compile(fr'SA_{pattern_prefix}_(.*?)\.xlsx')
    
    # Get all names from filenames
    names = []
    for f in os.listdir(folder_path):
        match = pattern.match(f)
        if match:
            names.append(match.group(1))
    
    # Initialize nested dictionary
    data_dict = {name: {} for name in names}
    
    # Read each file and its sheets
    for name in data_dict.keys():
        filename = f"SA_{pattern_prefix}_{name}.xlsx"
        file_path = os.path.join(folder_path, filename)
        
        try:
            # Read all sheets from the Excel file
            sheets = pd.read_excel(file_path, sheet_name=None)
            
            # Store each sheet (Fold_1 to Fold_5) in the dictionary
            for sheet_num in range(1, 6):
                sheet_name = f"Fold_{sheet_num}"
                if sheet_name in sheets:
                    data_dict[name][sheet_name] = sheets[sheet_name]
                else:
                    print(f"Warning: Sheet {sheet_name} not found in {filename}")
                    
        except FileNotFoundError:
            print(f"Warning: File {filename} not found in {folder_path}")
        except Exception as e:
            print(f"Error processing {filename}: {str(e)}")
    
    return data_dict

def average_folds(data_dict):
    """
    Calculate the average of all folds for each location.
    
    Args:
        data_dict (dict): Dictionary with location as keys and fold data as values
        
    Returns:
        dict: Dictionary with location as keys and averaged DataFrame as values
    """
    result = {}
    
    for location, fold_data in data_dict.items():
        # Collect all dataframes from folds
        all_folds = []
        
        for fold_name, df in fold_data.items():
            if isinstance(df, pd.DataFrame):
                all_folds.append(df)
        
        if not all_folds:
            continue
        
        # Concatenate all folds
        combined_df = pd.concat(all_folds, ignore_index=True)
        
        # Group by algorithm and calculate mean for numeric columns
        numeric_cols = combined_df.select_dtypes(include=[np.number]).columns
        avg_df = combined_df.groupby('Algorithm')[numeric_cols].mean().reset_index()
        
        result[location] = avg_df
    
    return result


def create_testing_cost_dataframe(averaged_results):
    """
    Create a pandas DataFrame with algorithms as index, locations as columns, and Testing Total Cost.
    
    Args:
        averaged_results (dict): Dictionary with location as keys and averaged DataFrames as values
        
    Returns:
        pd.DataFrame: Formatted table with testing costs
    """
    # Initialize data structure
    data_dict = {}
    
    for location, df in averaged_results.items():
        for _, row in df.iterrows():
            algorithm = row['Algorithm']
            testing_cost = row['Testing Total Cost']
            
            if algorithm not in data_dict:
                data_dict[algorithm] = {}
            
            data_dict[algorithm][location] = testing_cost
    
    # Convert to DataFrame
    result_df = pd.DataFrame.from_dict(data_dict, orient='index')
    
    # Sort rows (algorithms) and columns (locations)
    result_df = result_df.sort_index()  # Sort algorithms alphabetically
    result_df = result_df.reindex(sorted(result_df.columns), axis=1)  # Sort locations alphabetically
    
    # Format the values for better readability
    formatted_df = result_df.copy()
    for col in formatted_df.columns:
        formatted_df[col] = formatted_df[col].apply(lambda x: f"${x:,.2f}" if pd.notna(x) else "N/A")
    
    return result_df, formatted_df


def create_detailed_tables(averaged_results):
    """
    Create detailed tables for each location with specified columns for each algorithm.
    
    Args:
        averaged_results (dict): Dictionary with location as keys and averaged DataFrames as values
        
    Returns:
        dict: Dictionary with location as keys and formatted DataFrames as values
    """
    detailed_tables = {}
    
    for location, df in averaged_results.items():
        # Select and rename the required columns
        detailed_df = df[['Algorithm', 'PV_Size', 'Battery_Size', 'PCM_Heating_Size', 
                         'PCM_Cooling_Size', 'Testing Capital Cost', 
                         'Testing Operation Cost', 'Testing Total Cost']].copy()
        
        # Rename columns for better readability
        column_mapping = {
            'PV_Size': 'PV (kW)',
            'Battery_Size': 'Battery (kWh)',
            'PCM_Heating_Size': 'PCM_H (kWh)',
            'PCM_Cooling_Size': 'PCM_C (kWh)',
            'Testing Capital Cost': 'Testing Capital Cost ($)',
            'Testing Operation Cost': 'Testing Operational Cost ($)',
            'Testing Total Cost': 'Testing Total Cost ($)'
        }
        
        detailed_df = detailed_df.rename(columns=column_mapping)
        
        # Set Algorithm as index
        detailed_df = detailed_df.set_index('Algorithm')
        
        # Format numeric columns
        for col in detailed_df.columns:
            if 'Cost' in col:
                detailed_df[col] = detailed_df[col].apply(lambda x: f"${x:,.2f}")
            else:
                detailed_df[col] = detailed_df[col].round(2)
        
        detailed_tables[location] = detailed_df
    
    return detailed_tables

# Function to print the tables nicely
def print_detailed_tables(detailed_tables):
    """
    Print the detailed tables for each location in a formatted way.
    
    Args:
        detailed_tables (dict): Dictionary with location as keys and formatted DataFrames as values
    """
    for location, table in detailed_tables.items():
        print(f"\n{'='*80}")
        print(f"LOCATION: {location.upper()}")
        print(f"{'='*80}")
        print(table)
        print(f"{'='*80}")

# Alternative version that returns numeric values for calculations
def create_numeric_detailed_tables(averaged_results):
    """
    Create detailed tables with numeric values (not formatted as strings).
    
    Args:
        averaged_results (dict): Dictionary with location as keys and averaged DataFrames as values
        
    Returns:
        dict: Dictionary with location as keys and numeric DataFrames as values
    """
    numeric_tables = {}
    
    for location, df in averaged_results.items():
        # Select the required columns
        numeric_df = df[['Algorithm', 'PV_Size', 'Battery_Size', 'PCM_Heating_Size', 
                        'PCM_Cooling_Size', 'Testing Capital Cost', 
                        'Testing Operation Cost', 'Testing Total Cost']].copy()
        
        # Rename columns
        column_mapping = {
            'PV_Size': 'PV (kW)',
            'Battery_Size': 'Battery (kWh)',
            'PCM_Heating_Size': 'PCM_H (kWh)',
            'PCM_Cooling_Size': 'PCM_C (kWh)',
            'Testing Capital Cost': 'Testing Capital Cost ($)',
            'Testing Operation Cost': 'Testing Operational Cost ($)',
            'Testing Total Cost': 'Testing Total Cost ($)'
        }
        
        numeric_df = numeric_df.rename(columns=column_mapping)
        numeric_df = numeric_df.set_index('Algorithm')
        numeric_df = numeric_df.round(2)
        
        numeric_tables[location] = numeric_df
    
    return numeric_tables

# %%
def create_numeric_detailed_tables(averaged_results):
    """
    Create detailed tables with numeric values.
    """
    numeric_tables = {}
    
    for location, df in averaged_results.items():
        # Select the required columns
        numeric_df = df[['Algorithm', 'PV_Size', 'Battery_Size', 'PCM_Heating_Size', 
                        'PCM_Cooling_Size', 'Testing Capital Cost', 
                        'Testing Operation Cost', 'Testing Total Cost']].copy()
        
        # Rename columns
        column_mapping = {
            'PV_Size': 'PV (kW)',
            'Battery_Size': 'Battery (kWh)',
            'PCM_Heating_Size': 'PCM_H (kWh)',
            'PCM_Cooling_Size': 'PCM_C (kWh)',
            'Testing Capital Cost': 'Testing Capital Cost ($)',
            'Testing Operation Cost': 'Testing Operational Cost ($)',
            'Testing Total Cost': 'Testing Total Cost ($)'
        }
        
        numeric_df = numeric_df.rename(columns=column_mapping)
        numeric_df = numeric_df.set_index('Algorithm')
        numeric_df = numeric_df.round(2)
        
        numeric_tables[location] = numeric_df
    
    return numeric_tables

def export_tables_to_excel(numeric_tables, filename="location_analysis.xlsx"):
    """
    Export all numeric tables to an Excel file with each location as a separate sheet.
    """
    try:
        with pd.ExcelWriter(filename, engine='openpyxl') as writer:
            for location, table in numeric_tables.items():
                # No need for string replacement - data is already numeric
                table.to_excel(writer, sheet_name=location[:31])  # Excel sheet names max 31 chars
        
        print(f"Tables successfully exported to {filename}")
        return True
    except Exception as e:
        print(f"Error exporting to Excel: {e}")
        return False

# Main execution
SA_name = 'Scenarios'  # or 'Locations'

try:
    # Load data
    location_data = load_data(
        folder_path=os.path.join('Safe_Results', f'SA_{SA_name}'),
        pattern_prefix=SA_name
    )
    
    if not location_data:
        print("No data loaded. Check the folder path and file patterns.")
    else:
        print(f"Loaded data for locations: {list(location_data.keys())}")
        
        # Calculate averages
        averaged_results_loc = average_folds(location_data)
        
        # Get numeric tables
        numeric_tables = create_numeric_detailed_tables(averaged_results_loc)
        
        # Display sample of each table
        for location, table in numeric_tables.items():
            print(f"\n{location}:")
            print(table.head())
        
        # Export to Excel
        success = export_tables_to_excel(numeric_tables, "location_analysis.xlsx")
        
        # Export individual tables to CSV
        for location, table in numeric_tables.items():
            csv_filename = f"{location}_analysis.csv"
            table.to_csv(csv_filename)
            print(f"Exported {location} table to {csv_filename}")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Loaded data for locations: ['DC', 'FOB', 'RC']
#
# DC:
#            PV (kW)  Battery (kWh)  PCM_H (kWh)  PCM_C (kWh)  \
# Algorithm
# LP         2477.09        6264.09         0.71      4078.98
# RO         4299.12        5559.65         0.00      4435.44
# SO         2617.57        6471.94         0.00      3092.10
#
#            Testing Capital Cost ($)  Testing Operational Cost ($)  \
# Algorithm
# LP                        568088.27                     131535.08
# RO                        754595.15                      28812.73
# SO                        584972.84                     111741.65
#
#            Testing Total Cost ($)
# Algorithm
# LP                      699623.36
# RO                      783407.88
# SO                      696714.49
#
# FOB:
#            PV (kW)  Battery (kWh)  PCM_H (kWh)  PCM_C (kWh)  \
# Algorithm
# LP            5.57           6.10        38.11         0.14
# RO            6.71           7.97        45.91         0.00
# ...

# %%
SA_name = 'Capacity_Costs'

# Example usage for Locations:
location_data = load_data(
    folder_path=os.path.join('Safe_Results', f'SA_{SA_name}'),
    pattern_prefix=SA_name
)

# Example usage:
averaged_results_loc = average_folds(location_data)

# Get formatted tables for display
detailed_tables = create_detailed_tables(averaged_results_loc)
# print_detailed_tables(detailed_tables)

# Get numeric tables for calculations
numeric_tables = create_numeric_detailed_tables(averaged_results_loc)

# Export to Excel
export_tables_to_excel(numeric_tables, "location_analysis.xlsx")

# Or export individual tables to CSV
for location, table in numeric_tables.items():
    table.to_csv(f"{location}_analysis.csv")
    print(f"Exported {location} table to {location}_analysis.csv")
# Out:
# Tables successfully exported to location_analysis.xlsx
# Exported HPHB table to HPHB_analysis.csv
# Exported HPLB table to HPLB_analysis.csv
# Exported LPHB table to LPHB_analysis.csv
# Exported LPLB table to LPLB_analysis.csv

# %%
SA_name = 'Scenarios'

# Example usage for Locations:
scenario_data = load_data(
    folder_path=os.path.join('Safe_Results', f'SA_{SA_name}'),
    pattern_prefix=SA_name
)

# Example usage:
averaged_results_sce = average_folds(scenario_data)

# Example usage:
numeric_df_sce, formatted_df_sce = create_testing_cost_dataframe(averaged_results_sce)
print("Numeric DataFrame (for calculations):")
print(numeric_df_sce)
print("\nFormatted DataFrame (for display):")
print(formatted_df_sce)
# Out:
# Numeric DataFrame (for calculations):
#               DC         FOB          RC
# LP  699623.35560  2493.26588  3830.74292
# RO  783407.88288  2429.77244  3515.65216
# SO  696714.48520  2401.52664  3418.08168
#
# Formatted DataFrame (for display):
#              DC        FOB         RC
# LP  $699,623.36  $2,493.27  $3,830.74
# RO  $783,407.88  $2,429.77  $3,515.65
# SO  $696,714.49  $2,401.53  $3,418.08

# %%
SA_name = 'Capacity_Costs'

# Example usage for Locations:
cap_cost_data = load_data(
    folder_path=os.path.join('Safe_Results', f'SA_{SA_name}'),
    pattern_prefix=SA_name
)

# Example usage:
averaged_results_cap_cost = average_folds(cap_cost_data)

# Example usage:
numeric_df_cap_cost, formatted_df_cap_cost = create_testing_cost_dataframe(averaged_results_cap_cost)
print("Numeric DataFrame (for calculations):")
print(numeric_df_cap_cost)
print("\nFormatted DataFrame (for display):")
print(formatted_df_cap_cost)
# Out:
# Numeric DataFrame (for calculations):
#           HPHB        HPLB        LPHB        LPLB
# LP  2493.26588  2087.28504  1949.75136  1661.06536
# RO  2429.77244  2109.38756  1905.26892  1719.53312
# SO  2401.52664  2087.33548  1870.37588  1660.04368
#
# Formatted DataFrame (for display):
#          HPHB       HPLB       LPHB       LPLB
# LP  $2,493.27  $2,087.29  $1,949.75  $1,661.07
# RO  $2,429.77  $2,109.39  $1,905.27  $1,719.53
# SO  $2,401.53  $2,087.34  $1,870.38  $1,660.04
