# %%
import Data_Conversion
import Input_Parameters 
import Data_Conversion
import Passive_Model
import Solar_Generation
import Electrical_Load
import SO
# Out:
# /Users/jimmy/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
import numpy as np
import pandas as pd

# %%
# Sensitivity Analysis on Locations, Stochastic Optimization
# Fred Fan, Stanford University, 03/17/2025

# %%
# Define the base data directory, list of locations, and the weather year.
data_dir = "Data"
locations = ["Arizona", 
             "Alaska", 
             "Minnesota", 
             "Florida", 
             "HalfMoonBay"]

# 20 years of training data
weather_year_list_training = list(range(1998, 2018))  # use list(range(1998, 2018)) for full dataset
# 5 years of training data
weather_year_list_testing = list(range(2018, 2023))  # use list(range(2018, 2023)) for full dataset

# Set a random seed for consistency
# Define the number of rows (i) and columns (j)
i = len(locations)  # Number of rows
j = len(weather_year_list_training) + len(weather_year_list_testing)  # Number of columns

# Generate a sequential array of numbers starting from 1
total_cells = i * j  # Total number of cells in the DataFrame
sequential_numbers = np.arange(1, total_cells + 1)  # Generates 1, 2, 3, ..., i*j

# Reshape the array into a 2D array with i rows and j columns
data = sequential_numbers.reshape(i, j)

# Convert the array into a DataFrame
random_seeds = pd.DataFrame(data, columns=[f'Column_{k+1}' for k in range(j)])

lats, lons, timezones = Data_Conversion.get_timezones(data_dir, locations)
# Out:
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_1998.csv
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_1998.csv
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_1998.csv
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_1998.csv
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_1998.csv

# %%
# Create dictionary for recording results
training_results = {}  # Initialize as an empty dictionary

# %%
len(weather_year_list_training)
# Out:
# 20

# %%
# Sensitivity Analysis on Locations

for i in range(len(locations)):
    # Initialize storing space to store all input_dfs
    input_df_list_train = []

    for j in range(len(weather_year_list_training)):
        
        location = locations[i]
        year = weather_year_list_training[j]

        # Get a unique random seed number
        random_seed = random_seeds.iloc[i, j]
        print(random_seed)
        
        # Read NSRDB weather data of the given location of the given year
        NSRDB_raw_weather = Data_Conversion.read_NSRDB(data_dir, location, year)

        # Prepare weather data file using NSRDB data
        weather_data = Data_Conversion.prepare_NSRDB(NSRDB_raw_weather, lats[i], lons[i], timezones[i])

        # Prepare heating and cooling load using weather data and passive model
        NetHeatTransfers = Passive_Model.passive_model(Input_Parameters.calibration_file_path, weather_data, Input_Parameters.T_indoor_constant, lats[i])

        # Prepare solar PV capacity factor using weather data
        pv_cf = Solar_Generation.generate_pv(weather_data, lats[i])

        # Prepare occupancy and electrical load schedule using for a specific random seed number for a specific year at a specific location
        load_sched = Electrical_Load.generate_schedules("bayes", weather_data, random_seed)
        
        # Combine all relative input data as input_df, which will be the input of the capacity optimization algorithm
        input_df = Data_Conversion.combine_input_NSRDB(weather_data, load_sched, pv_cf, NetHeatTransfers)
        
        # Add input_df to list
        input_df_list_train.append(input_df)

    # Run optimization function (Replace with SO)
    PV_Size, Battery_Size, PCM_Heating_Size, PCM_Cooling_Size, ObjValue, First_stage_cost, Second_stage_cost = SO.SO_training(input_df_list_train, Input_Parameters.lossofloadcost)

    # Store the variables in the nested dictionary
    training_results[location] = {
        'PV_Size': PV_Size,
        'Battery_Size': Battery_Size,
        'PCM_Heating_Size': PCM_Heating_Size,
        'PCM_Cooling_Size': PCM_Cooling_Size,
        'Total Cost': ObjValue,
        'Capital Cost': First_stage_cost,
        'Operation Cost': Second_stage_cost
    }
# Out:
# 1
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06
#   56   3.21059220e+04  3.21059198e+04  1.64e-06 7.53e-13  5.64e-10    66s
#   57   3.21059212e+04  3.21059212e+04  1.18e-07 7.43e-11  1.71e-13    66s
#
# Barrier solved model in 57 iterations and 65.99 seconds (121.24 work units)
# Optimal objective 3.21059212e+04
#
# Crossover log...
#
#   385829 DPushes remaining with DInf 0.0000000e+00                67s
#        0 DPushes remaining with DInf 0.0000000e+00                69s
#
#   698444 PPushes remaining with PInf 0.0000000e+00                69s
#   436660 PPushes remaining with PInf 0.0000000e+00                70s
#    23580 PPushes remaining with PInf 0.0000000e+00                75s
#        0 PPushes remaining with PInf 0.0000000e+00                79s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.4108867e-13     79s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   891215    3.2105921e+04   0.000000e+00   0.000000e+00     82s
#
# Solved with barrier
# Solved in 891215 iterations and 82.03 seconds (141.52 work units)
# Optimal objective  3.210592116e+04
# 76
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_1998.csv
# 77
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_1999.csv
# 78
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2000.csv
# 79
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2001.csv
# 80
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2002.csv
# 81
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2003.csv
# 82
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2004.csv
# 83
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2005.csv
# 84
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2006.csv
# 85
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2007.csv
# 86
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2008.csv
# 87
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2009.csv
# 88
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2010.csv
# 89
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2011.csv
# 90
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2012.csv
# 91
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2013.csv
# 92
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2014.csv
# 93
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2015.csv
# 94
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2016.csv
# 95
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2017.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpv7k7l69p.pyomo.lp
# Reading time = 6.82 seconds
# x1: 3153660 rows, 2803205 columns, 8496359 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 3153660 rows, 2803205 columns and 8496359 nonzeros
# Model fingerprint: 0x30736bab
# Coefficient statistics:
#   Matrix range     [8e-04, 1e+00]
#   Objective range  [3e+01, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [7e-15, 2e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 946342 rows and 771183 columns (presolve time = 11s) ...
# Presolve removed 1006948 rows and 771183 columns
# Presolve time: 15.05s
# Presolved: 2146712 rows, 2032022 columns, 8823325 nonzeros
#
# Ordering time: 1.39s
#
# Barrier statistics:
#  Dense cols : 4
#  AA' NZ     : 1.426e+07
#  Factor NZ  : 4.158e+07 (roughly 2.0 GB of memory)
#  Factor Ops : 8.474e+08 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.14992886e+09 -6.62122751e+07  5.18e+02 0.00e+00  1.69e+03    20s
#    1   4.58807851e+08 -9.79403038e+07  1.60e+02 1.56e+00  5.44e+02    20s
#    2   1.92906779e+08 -9.67666577e+07  7.60e+01 7.39e-01  2.43e+02    21s
#    3   8.31883275e+07 -8.35308584e+07  2.88e+01 4.47e-01  1.24e+02    22s
#    4   3.39670791e+07 -6.80417051e+07  1.12e+01 2.85e-01  7.06e+01    22s
#    5   9.70962957e+06 -3.75157930e+07  3.47e+00 1.27e-01  3.01e+01    23s
#    6   9.76858729e+05 -7.58308847e+06  3.04e-01 1.87e-02  4.69e+00    24s
#    7   1.28699041e+05 -1.18657554e+06  4.10e-04 2.94e-03  7.19e-01    24s
#    8   1.13456580e+05 -6.72877075e+05  1.42e-04 1.63e-03  4.07e-01    25s
#    9   1.02242110e+05 -4.47759513e+05  6.91e-05 1.06e-03  2.70e-01    26s
#   10   8.98551345e+04 -2.92440333e+05  3.25e-05 7.05e-04  1.79e-01    26s
#   11   8.42519560e+04 -2.44936686e+05  2.48e-05 6.02e-04  1.51e-01    27s
#   12   7.61530356e+04 -1.70770457e+05  1.65e-05 4.39e-04  1.09e-01    27s
#   13   6.64853234e+04 -9.54014371e+04  9.83e-06 2.73e-04  6.69e-02    28s
#   14   5.82801864e+04 -2.79549281e+04  6.33e-06 1.22e-04  3.22e-02    29s
#   49   2.08377842e+04  2.08376341e+04  9.54e-10 1.61e-12  3.95e-08    59s
#   50   2.08376924e+04  2.08376507e+04  1.76e-09 3.58e-12  1.10e-08    59s
#   51   2.08376616e+04  2.08376608e+04  2.72e-10 6.25e-13  2.18e-10    60s
#   52   2.08376612e+04  2.08376612e+04  1.06e-09 5.00e-11  7.33e-15    60s
#
# Barrier solved model in 52 iterations and 60.44 seconds (111.30 work units)
# Optimal objective 2.08376612e+04
#
# Crossover log...
#
#   385614 DPushes remaining with DInf 0.0000000e+00                61s
#        0 DPushes remaining with DInf 0.0000000e+00                64s
#
#   698710 PPushes remaining with PInf 0.0000000e+00                64s
#   500098 PPushes remaining with PInf 0.0000000e+00                65s
#   122629 PPushes remaining with PInf 0.0000000e+00                71s
#    29329 PPushes remaining with PInf 0.0000000e+00                75s
#     2818 PPushes remaining with PInf 0.0000000e+00                80s
#        0 PPushes remaining with PInf 0.0000000e+00                83s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.4319356e-14     83s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   893862    2.0837661e+04   0.000000e+00   0.000000e+00     86s
#
# Solved with barrier
# Solved in 893862 iterations and 87.91 seconds (145.33 work units)
# Optimal objective  2.083766116e+04
# 101
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_1998.csv
# 102
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_1999.csv
# 103
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2000.csv
# 104
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2001.csv
# 105
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2002.csv
# 106
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2003.csv
# 107
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2004.csv
# 108
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2005.csv
# 109
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2006.csv
# 110
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2007.csv
# 111
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2008.csv
# 112
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2009.csv
# 113
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2010.csv
# 114
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2011.csv
# 115
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2012.csv
# 116
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2013.csv
# 117
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2014.csv
# 118
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2015.csv
# 119
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2016.csv
# 120
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2017.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp30avyo4m.pyomo.lp
# Reading time = 6.42 seconds
# x1: 3153660 rows, 2803205 columns, 8496599 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 3153660 rows, 2803205 columns and 8496599 nonzeros
# Model fingerprint: 0x5ea30400
# Coefficient statistics:
#   Matrix range     [8e-04, 1e+00]
#   Objective range  [3e+01, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-05, 2e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 945882 rows and 770723 columns (presolve time = 9s) ...
# Presolve removed 1009276 rows and 770723 columns
# Presolve time: 13.40s
# Presolved: 2144384 rows, 2032482 columns, 8817747 nonzeros
#
# Ordering time: 1.34s
#
# Barrier statistics:
#  Dense cols : 4
#  AA' NZ     : 1.422e+07
#  Factor NZ  : 4.158e+07 (roughly 2.0 GB of memory)
#  Factor Ops : 8.493e+08 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.15137659e+09 -7.83065723e+07  5.18e+02 0.00e+00  1.95e+03    18s
#    1   3.83739469e+08 -1.10438908e+08  1.46e+02 1.98e+00  5.79e+02    18s
#    2   1.60116027e+08 -1.07923844e+08  5.70e+01 8.37e-01  2.43e+02    19s
#    3   6.67940803e+07 -8.75996877e+07  2.20e+01 3.74e-01  1.09e+02    20s
#    4   2.48408843e+07 -5.45788955e+07  8.58e+00 1.44e-01  4.49e+01    21s
#    5   3.87673314e+06 -2.45569360e+07  2.15e+00 5.06e-02  1.46e+01    21s
#    6   2.52228279e+05 -3.28061969e+06  1.53e-02 5.39e-03  1.63e+00    22s
#    7   1.51207043e+05 -9.39241512e+05  3.24e-03 1.55e-03  4.82e-01    22s
#    8   1.24121873e+05 -5.17844931e+05  1.71e-03 8.60e-04  2.73e-01    23s
#    9   1.03875238e+05 -3.41281652e+05  9.28e-04 5.78e-04  1.83e-01    24s
#   10   8.92322205e+04 -2.44838408e+05  5.70e-04 4.23e-04  1.33e-01    25s
#   11   7.89523848e+04 -1.61687560e+05  3.78e-04 2.96e-04  9.25e-02    25s
#   46   2.15111894e+04  2.10268204e+04  7.13e-07 2.26e-08  1.29e-04    56s
#   47   2.15051498e+04  2.10463232e+04  6.86e-07 2.02e-08  1.22e-04    57s
#   48   2.15007682e+04  2.11164932e+04  6.62e-07 1.50e-08  1.02e-04    58s
#   49   2.14803998e+04  2.11652797e+04  5.31e-07 1.16e-08  8.37e-05    59s
#   50   2.14687268e+04  2.11863330e+04  4.40e-07 1.15e-08  7.51e-05    60s
#   51   2.14567887e+04  2.12815499e+04  3.32e-07 3.56e-08  4.65e-05    61s
#   52   2.14433351e+04  2.13401319e+04  2.16e-07 1.21e-08  2.74e-05    62s
#   53   2.14395699e+04  2.13567113e+04  1.87e-07 8.71e-09  2.20e-05    63s
#   54   2.14313753e+04  2.13777729e+04  1.27e-07 4.78e-09  1.42e-05    64s
#   55   2.14231507e+04  2.14042329e+04  8.12e-08 1.59e-10  5.00e-06    65s
#   56   2.14182130e+04  2.14108649e+04  4.34e-08 4.81e-12  1.93e-06    66s
#   57   2.14150367e+04  2.14117796e+04  4.99e-08 5.06e-12  8.57e-07    66s
#   58   2.14137418e+04  2.14120104e+04  2.54e-08 1.18e-11  4.55e-07    67s
#   59   2.14126609e+04  2.14122387e+04  2.22e-08 3.07e-11  1.11e-07    67s
#   60   2.14124678e+04  2.14122995e+04  1.65e-08 1.10e-11  4.42e-08    68s
#   61   2.14123545e+04  2.14123151e+04  5.05e-09 6.61e-12  1.03e-08    69s
#   62   2.14123237e+04  2.14123234e+04  3.82e-08 4.88e-11  6.18e-11    69s
#   63   2.14123235e+04  2.14123235e+04  4.47e-10 3.38e-11  6.39e-16    70s
#
# Barrier solved model in 63 iterations and 69.86 seconds (128.17 work units)
# Optimal objective 2.14123235e+04
#
# Crossover log...
#
#   385717 DPushes remaining with DInf 0.0000000e+00                71s
#        0 DPushes remaining with DInf 0.0000000e+00                74s
#
#   699121 PPushes remaining with PInf 0.0000000e+00                74s
#   474081 PPushes remaining with PInf 0.0000000e+00                75s
#    76221 PPushes remaining with PInf 0.0000000e+00                81s
#     6390 PPushes remaining with PInf 0.0000000e+00                86s
#        0 PPushes remaining with PInf 0.0000000e+00                90s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.1801919e-03     90s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   881104    2.1412323e+04   0.000000e+00   5.180192e-03     91s
#   881106    2.1412323e+04   0.000000e+00   0.000000e+00     93s
#
# Solved with barrier
# Solved in 881106 iterations and 95.66 seconds (156.14 work units)
# Optimal objective  2.141232348e+04

# %%
print(training_results)
# Out:
# {'Arizona': {'PV_Size': 17.899, 'Battery_Size': 18.708, 'PCM_Heating_Size': 57.773, 'PCM_Cooling_Size': 0.0, 'Total Cost': 22978.102, 'Capital Cost': 22877.576, 'Operation Cost': 100.526}, 'Alaska': {'PV_Size': 213.745, 'Battery_Size': 32.656, 'PCM_Heating_Size': 222.485, 'PCM_Cooling_Size': 0.0, 'Total Cost': 44556.382, 'Capital Cost': 43853.028, 'Operation Cost': 703.355}, 'Minnesota': {'PV_Size': 75.416, 'Battery_Size': 16.055, 'PCM_Heating_Size': 196.797, 'PCM_Cooling_Size': 0.0, 'Total Cost': 32105.921, 'Capital Cost': 30662.699, 'Operation Cost': 1443.222}, 'Florida': {'PV_Size': 6.829, 'Battery_Size': 14.676, 'PCM_Heating_Size': 0.0, 'PCM_Cooling_Size': 28.665, 'Total Cost': 20837.661, 'Capital Cost': 20814.977, 'Operation Cost': 22.684}, 'HalfMoonBay': {'PV_Size': 12.52, 'Battery_Size': 6.54, 'PCM_Heating_Size': 59.533, 'PCM_Cooling_Size': 0.0, 'Total Cost': 21412.323, 'Capital Cost': 21161.769, 'Operation Cost': 250.555}}

# %%
# Testing:

# Create the nested dictionary
testing_results = {location: {year: {} for year in weather_year_list_testing} for location in locations}

for i in range(len(locations)):
    location = locations[i]
    test_capacities = [training_results[location]['PV_Size'], training_results[location]['Battery_Size'], training_results[location]['PCM_Heating_Size'], training_results[location]['PCM_Cooling_Size']]
    for j in range(len(weather_year_list_testing)):
        year = weather_year_list_testing[j]
        
        # Get a unique random seed number
        random_seed = random_seeds.iloc[i, j+len(weather_year_list_training)]
        print(random_seed)
        
        # Read NSRDB weather data of the given location of the given year
        NSRDB_raw_weather = Data_Conversion.read_NSRDB(data_dir, location, year)

        # Prepare weather data file using NSRDB data
        weather_data = Data_Conversion.prepare_NSRDB(NSRDB_raw_weather, lats[i], lons[i], timezones[i])

        # Prepare heating and cooling load using weather data and passive model
        NetHeatTransfers = Passive_Model.passive_model(Input_Parameters.calibration_file_path, weather_data, Input_Parameters.T_indoor_constant, lats[i])

        # Prepare solar PV capacity factor using weather data
        pv_cf = Solar_Generation.generate_pv(weather_data, lats[i])

        # Prepare occupancy and electrical load schedule using for a specific random seed number for a specific year at a specific location
        load_sched = Electrical_Load.generate_schedules("bayes", weather_data, random_seed)
        
        # Combine all relative input data as input_df, which will be the input of the capacity optimization algorithm
        input_df = Data_Conversion.combine_input_NSRDB(weather_data, load_sched, pv_cf, NetHeatTransfers)
    
        ObjValue, First_stage_cost, Second_stage_cost = SO.simulate(input_df, Input_Parameters.lossofloadcost, test_capacities)
        # Store the variables in the nested dictionary
        testing_results[location][year] = {
            'Total Cost': ObjValue,
            'Capital Cost': First_stage_cost,
            'Operation Cost': Second_stage_cost
        }
# Out:
# 21
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2018.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpk6bqv6c1.pyomo.lp
# Reading time = 0.29 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x9ce39549
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-04, 1e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 92016 rows and 55758 columns
# Presolve time: 0.17s
# Presolved: 65667 rows, 84402 columns, 206036 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.513e+05
#  Factor NZ  : 6.245e+05 (roughly 70 MB of memory)
#  Factor Ops : 6.945e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.57926026e+08 -9.39109364e+07  1.29e+02 0.00e+00  4.05e+03     0s
#    1   5.95744084e+07 -5.00907917e+07  4.24e+01 1.71e-13  1.09e+03     0s
#    2   1.06874128e+07 -1.45698982e+07  7.01e+00 3.50e-12  2.02e+02     0s
#    3   1.07866703e+06 -3.44045763e+06  7.68e-01 2.61e-12  3.22e+01     0s
#    4   2.83752249e+05 -3.65786436e+05  1.98e-01 6.00e-13  4.51e+00     0s
#
# Barrier performed 4 iterations in 0.39 seconds (0.37 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20729 iterations and 0.41 seconds (0.40 work units)
# Optimal objective  5.667155181e+02
# 22
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2019.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmps2mclmyn.pyomo.lp
# Reading time = 0.27 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x2a9b8928
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e-05, 1e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 92008 rows and 55739 columns
# Presolve time: 0.15s
# Presolved: 65675 rows, 84421 columns, 206062 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.513e+05
#  Factor NZ  : 6.245e+05 (roughly 70 MB of memory)
#  Factor Ops : 6.947e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.59236289e+08 -9.37789087e+07  1.30e+02 0.00e+00  4.08e+03     0s
#    1   6.01321678e+07 -5.04110194e+07  4.29e+01 1.71e-13  1.10e+03     0s
#    2   9.35787485e+06 -1.39903283e+07  6.31e+00 3.04e-12  1.85e+02     0s
#
# Barrier performed 2 iterations in 0.34 seconds (0.30 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20799 iterations and 0.36 seconds (0.40 work units)
# Optimal objective  0.000000000e+00
# 23
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2020.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpo059ktkf.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x93a19fd6
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-13, 1e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 92017 rows and 55755 columns
# Presolve time: 0.16s
# Presolved: 65666 rows, 84405 columns, 206030 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.513e+05
#  Factor NZ  : 6.244e+05 (roughly 70 MB of memory)
#  Factor Ops : 6.945e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.56791718e+08 -9.37598866e+07  1.28e+02 0.00e+00  4.02e+03     0s
#    1   5.88684388e+07 -4.98291924e+07  4.18e+01 1.71e-13  1.07e+03     0s
#    2   1.04217622e+07 -1.43654311e+07  6.84e+00 2.27e-12  1.97e+02     0s
#
# Barrier performed 2 iterations in 0.35 seconds (0.30 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20781 iterations and 0.37 seconds (0.39 work units)
# Optimal objective  0.000000000e+00
# 24
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2021.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpci_f_tv5.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xa8e3c05a
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-04, 2e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 92022 rows and 55760 columns
# Presolve time: 0.17s
# Presolved: 65661 rows, 84400 columns, 206034 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.513e+05
#  Factor NZ  : 6.244e+05 (roughly 70 MB of memory)
#  Factor Ops : 6.944e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.58195642e+08 -9.38845308e+07  1.29e+02 0.00e+00  4.06e+03     0s
#    1   5.96235428e+07 -5.02124006e+07  4.24e+01 1.71e-13  1.09e+03     0s
#    2   1.06048626e+07 -1.44937741e+07  6.95e+00 1.55e-11  2.00e+02     0s
#    3   1.23728407e+06 -2.83187981e+06  8.50e-01 2.44e-12  2.92e+01     0s
#    4   5.18499010e+04 -1.77391003e+05  3.41e-02 2.27e-13  1.58e+00     0s
#
# Barrier performed 4 iterations in 0.39 seconds (0.37 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20568 iterations and 0.40 seconds (0.39 work units)
# Optimal objective  0.000000000e+00
# 25
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2022.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp1wcf41r4.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x3d5e0684
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-14, 1e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 92012 rows and 55760 columns
# Presolve time: 0.17s
# Presolved: 65671 rows, 84400 columns, 206058 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.513e+05
#  Factor NZ  : 6.245e+05 (roughly 70 MB of memory)
#  Factor Ops : 6.946e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.60461434e+08 -9.38162018e+07  1.32e+02 0.00e+00  4.11e+03     0s
#    1   6.01995363e+07 -5.09808211e+07  4.31e+01 1.71e-13  1.11e+03     0s
#    2   1.13376570e+07 -1.48282898e+07  7.49e+00 9.55e-12  2.10e+02     0s
#    3   1.56278913e+06 -3.37391407e+06  1.07e+00 4.41e-12  3.55e+01     0s
#    4   1.99087051e+05 -1.76091841e+05  1.40e-01 6.86e-13  2.60e+00     0s
#
# Barrier performed 4 iterations in 0.38 seconds (0.37 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20441 iterations and 0.41 seconds (0.39 work units)
# Optimal objective  1.086513864e+03
# 46
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2018.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp_cwr5gj8.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x4c344dbc
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-03, 2e+08]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 94437 rows and 60578 columns
# Presolve time: 0.17s
# Presolved: 63246 rows, 79582 columns, 197269 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.459e+05
#  Factor NZ  : 6.389e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.596e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.93265782e+08 -1.76696964e+08  3.03e+02 0.00e+00  5.99e+03     0s
#    1   6.28502414e+07 -6.64239531e+07  8.81e+01 4.20e-02  1.36e+03     0s
#    2   8.04682172e+06 -1.93886359e+07  1.08e+01 2.61e-12  2.21e+02     0s
#    3   1.53175838e+06 -3.93604744e+06  2.06e+00 7.60e-13  4.04e+01     0s
#
# Barrier performed 3 iterations in 0.37 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 15332 iterations and 0.37 seconds (0.40 work units)
# Optimal objective  0.000000000e+00
# 47
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2019.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpk4vnovz4.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x4b6b5f41
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-03, 1e+08]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 94621 rows and 61315 columns
# Presolve time: 0.17s
# Presolved: 63062 rows, 78845 columns, 195913 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.448e+05
#  Factor NZ  : 6.510e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.933e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.80540653e+08 -1.70840677e+08  2.82e+02 0.00e+00  5.81e+03     0s
#    1   5.89869972e+07 -6.53185330e+07  8.24e+01 1.71e-13  1.32e+03     0s
#    2   7.56635941e+06 -1.91306617e+07  1.02e+01 2.27e-12  2.16e+02     0s
#    3   1.11982056e+06 -3.05449689e+06  1.52e+00 6.47e-13  3.08e+01     0s
#
# Barrier performed 3 iterations in 0.36 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 13815 iterations and 0.36 seconds (0.37 work units)
# Optimal objective  0.000000000e+00
# 48
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2020.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmppj5za0ua.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xe3192b22
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-03, 1e+08]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 94704 rows and 61488 columns
# Presolve time: 0.17s
# Presolved: 62979 rows, 78672 columns, 195593 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.446e+05
#  Factor NZ  : 6.513e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.951e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.75300093e+08 -1.68615171e+08  2.78e+02 0.00e+00  5.68e+03     0s
#    1   5.65388259e+07 -6.38946706e+07  8.03e+01 1.71e-13  1.27e+03     0s
#    2   7.48079790e+06 -1.88958538e+07  1.03e+01 4.32e-12  2.14e+02     0s
#    3   6.63555527e+05 -3.76352734e+06  9.31e-01 7.18e-13  3.23e+01     0s
#
# Barrier performed 3 iterations in 0.36 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 14742 iterations and 0.36 seconds (0.37 work units)
# Optimal objective  0.000000000e+00
# 49
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2021.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp5mt29sdz.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x03c9eadd
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-04, 1e+08]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 94771 rows and 61643 columns
# Presolve time: 0.16s
# Presolved: 62912 rows, 78517 columns, 195293 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.444e+05
#  Factor NZ  : 6.504e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.933e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.72659720e+08 -1.67356414e+08  2.78e+02 0.00e+00  5.63e+03     0s
#    1   5.57671216e+07 -6.36955631e+07  8.05e+01 1.71e-13  1.27e+03     0s
#    2   7.40777976e+06 -1.83988700e+07  1.04e+01 2.16e-12  2.10e+02     0s
#    3   9.99450393e+05 -2.70914543e+06  1.38e+00 5.04e-13  2.73e+01     0s
#
# Barrier performed 3 iterations in 0.32 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 14493 iterations and 0.32 seconds (0.37 work units)
# Optimal objective  0.000000000e+00
# 50
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2022.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpgph23a6q.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x293ab547
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 3e+08]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 94375 rows and 60830 columns
# Presolve time: 0.17s
# Presolved: 63308 rows, 79330 columns, 196889 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.455e+05
#  Factor NZ  : 6.499e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.858e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.85961976e+08 -1.73086739e+08  2.81e+02 0.00e+00  5.88e+03     0s
#    1   6.00965175e+07 -6.61382244e+07  8.14e+01 1.36e-02  1.33e+03     0s
#    2   8.51177893e+06 -1.88586230e+07  1.12e+01 2.39e-12  2.23e+02     0s
#    3   5.71253180e+05 -2.61041706e+06  7.07e-01 6.54e-13  2.30e+01     0s
#
# Barrier performed 3 iterations in 0.35 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 14581 iterations and 0.36 seconds (0.37 work units)
# Optimal objective  0.000000000e+00
# 71
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2018.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpwj1ztu9j.pyomo.lp
# Reading time = 0.29 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x5fac04bb
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-14, 2e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 92981 rows and 58001 columns
# Presolve time: 0.17s
# Presolved: 64702 rows, 82159 columns, 202388 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.493e+05
#  Factor NZ  : 6.252e+05 (roughly 60 MB of memory)
#  Factor Ops : 6.949e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.72155889e+08 -1.53923232e+08  1.69e+02 0.00e+00  4.84e+03     0s
#    1   6.40728629e+07 -5.01227344e+07  5.64e+01 1.71e-13  1.15e+03     0s
#    2   9.28760763e+06 -1.43337373e+07  7.91e+00 1.04e-11  1.90e+02     0s
#    3   7.79012129e+05 -2.91092104e+06  6.52e-01 1.48e-12  2.65e+01     0s
#    4   2.69296452e+03 -9.49335444e+04  9.48e-04 2.27e-13  6.80e-01     0s
#
# Barrier performed 4 iterations in 0.43 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20868 iterations and 0.44 seconds (0.47 work units)
# Optimal objective  0.000000000e+00
# 72
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2019.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmply_rsbda.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x40d84ca1
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-14, 2e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 92965 rows and 57920 columns
# Presolve time: 0.17s
# Presolved: 64718 rows, 82240 columns, 202512 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.493e+05
#  Factor NZ  : 6.268e+05 (roughly 60 MB of memory)
#  Factor Ops : 6.977e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.76502597e+08 -1.55318281e+08  1.73e+02 0.00e+00  4.96e+03     0s
#    1   6.52984080e+07 -5.15500523e+07  5.74e+01 1.71e-13  1.18e+03     0s
#    2   1.05768814e+07 -1.49883275e+07  9.00e+00 7.76e-12  2.08e+02     0s
#    3   1.41930902e+06 -2.74480012e+06  1.21e+00 1.56e-12  3.05e+01     0s
#    4   1.01515194e+06 -6.69366458e+05  8.89e-01 3.23e-13  1.21e+01     0s
#
# Barrier performed 4 iterations in 0.47 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20868 iterations and 0.47 seconds (0.48 work units)
# Optimal objective  5.277439321e+03
# 73
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2020.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp5l_e6s5s.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x0ab9ab52
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-05, 2e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 93026 rows and 58086 columns
# Presolve time: 0.17s
# Presolved: 64657 rows, 82074 columns, 202219 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.492e+05
#  Factor NZ  : 6.268e+05 (roughly 60 MB of memory)
#  Factor Ops : 6.992e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.76434752e+08 -1.55159049e+08  1.74e+02 0.00e+00  4.98e+03     0s
#    1   6.54685754e+07 -5.19936839e+07  5.82e+01 1.71e-13  1.20e+03     0s
#    2   8.96806558e+06 -1.48791115e+07  7.67e+00 5.29e-12  1.91e+02     0s
#    3   8.16754366e+05 -2.67406277e+06  6.83e-01 1.83e-12  2.51e+01     0s
#    4   1.33528141e+05 -2.58059630e+05  1.34e-01 1.71e-13  2.75e+00     0s
#
# Barrier performed 4 iterations in 0.43 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20635 iterations and 0.45 seconds (0.48 work units)
# Optimal objective  0.000000000e+00
# 74
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2021.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp6ibg34cx.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xd8f2a322
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-04, 2e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 93095 rows and 58221 columns
# Presolve time: 0.17s
# Presolved: 64588 rows, 81939 columns, 201939 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.489e+05
#  Factor NZ  : 6.302e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.069e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.78083838e+08 -1.55600061e+08  1.78e+02 0.00e+00  5.05e+03     0s
#    1   6.57943757e+07 -5.29663724e+07  5.91e+01 2.27e-13  1.22e+03     0s
#    2   1.01903711e+07 -1.56137885e+07  8.59e+00 5.43e-12  2.09e+02     0s
#    3   5.39327709e+05 -2.56999831e+06  4.51e-01 2.67e-12  2.22e+01     0s
#    4   3.15830231e+03 -4.11275595e+04  1.66e-03 2.27e-13  3.09e-01     0s
#
# Barrier performed 4 iterations in 0.42 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 19618 iterations and 0.43 seconds (0.44 work units)
# Optimal objective  0.000000000e+00
# 75
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2022.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpbgop2hmi.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x88585a92
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-14, 2e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 93079 rows and 58094 columns
# Presolve time: 0.17s
# Presolved: 64604 rows, 82066 columns, 202086 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.489e+05
#  Factor NZ  : 6.266e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.001e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.72056349e+08 -1.53790215e+08  1.69e+02 0.00e+00  4.85e+03     0s
#    1   6.45562273e+07 -5.03153012e+07  5.72e+01 2.27e-13  1.16e+03     0s
#    2   9.44148091e+06 -1.45393109e+07  8.09e+00 4.43e-12  1.94e+02     0s
#    3   1.07043551e+06 -2.68481443e+06  8.96e-01 1.01e-12  2.72e+01     0s
#    4   6.74980847e+03 -1.40866025e+05  3.86e-03 2.27e-13  1.03e+00     0s
#
# Barrier performed 4 iterations in 0.44 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 21055 iterations and 0.45 seconds (0.50 work units)
# Optimal objective  0.000000000e+00
# 96
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2018.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpg85irsxn.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xc5d452fd
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-14, 3e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 93588 rows and 55836 columns
# Presolve time: 0.17s
# Presolved: 64095 rows, 84324 columns, 203196 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.458e+05
#  Factor NZ  : 6.369e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.388e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.27319522e+08 -7.72222972e+07  9.19e+01 0.00e+00  3.23e+03     0s
#    1   5.23326387e+07 -3.47842522e+07  3.17e+01 1.71e-13  8.76e+02     0s
#    2   5.25225881e+06 -7.98559610e+06  3.07e+00 1.71e-13  1.06e+02     0s
#    3   8.21499865e+05 -2.01600226e+06  4.98e-01 1.71e-13  2.07e+01     0s
#    4   5.85190293e+04 -2.44278140e+05  3.21e-02 2.27e-13  2.11e+00     0s
#    5   1.18867089e+03 -3.40702049e+03  6.28e-04 2.27e-13  3.19e-02     0s
#
# Barrier performed 5 iterations in 0.45 seconds (0.39 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Solved in 26670 iterations and 0.46 seconds (0.64 work units)
# Optimal objective  0.000000000e+00
# 97
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2019.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp1l7pxvee.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xbb4db767
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-14, 3e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 93441 rows and 55689 columns
# Presolve time: 0.17s
# Presolved: 64242 rows, 84471 columns, 203620 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.461e+05
#  Factor NZ  : 6.389e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.401e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.27202848e+08 -7.72099924e+07  9.19e+01 0.00e+00  3.23e+03     0s
#    1   5.23379731e+07 -3.48376976e+07  3.18e+01 2.27e-13  8.76e+02     0s
#    2   5.65885906e+06 -7.65835735e+06  3.33e+00 1.71e-13  1.08e+02     0s
#    3   8.82412226e+05 -1.95335441e+06  5.08e-01 1.71e-13  2.06e+01     0s
#    4   8.35526356e+04 -2.20249335e+05  4.69e-02 1.71e-13  2.12e+00     0s
#    5   3.44332974e+03 -7.62540284e+03  1.90e-03 2.27e-13  7.68e-02     0s
#    6   1.24634654e-01 -1.10528768e+00  6.65e-08 2.27e-13  8.53e-06     0s
#
# Barrier performed 6 iterations in 0.47 seconds (0.41 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Solved in 27752 iterations and 0.48 seconds (0.68 work units)
# Optimal objective  0.000000000e+00
# 98
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2020.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpp57t07wp.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x4fbae59f
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-15, 3e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 93478 rows and 55696 columns
# Presolve time: 0.17s
# Presolved: 64205 rows, 84464 columns, 203536 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.460e+05
#  Factor NZ  : 6.398e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.423e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.27226932e+08 -7.72311693e+07  9.19e+01 0.00e+00  3.23e+03     0s
#    1   5.24930185e+07 -3.47482159e+07  3.19e+01 1.71e-13  8.78e+02     0s
#    2   4.75589125e+06 -7.87235731e+06  2.78e+00 1.71e-13  1.01e+02     0s
#    3   5.71289498e+05 -2.03741836e+06  3.22e-01 1.71e-13  1.87e+01     0s
#    4   2.77140767e+04 -1.16438793e+05  1.46e-02 1.71e-13  1.00e+00     0s
#    5   4.06696074e+00 -8.17704895e+01  9.94e-07 1.71e-13  5.96e-04     0s
#
# Barrier performed 5 iterations in 0.45 seconds (0.39 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Solved in 26699 iterations and 0.45 seconds (0.63 work units)
# Optimal objective  0.000000000e+00
# 99
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2021.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp4un25cdv.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xf2c723f0
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-14, 3e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 93375 rows and 55688 columns
# Presolve time: 0.17s
# Presolved: 64308 rows, 84472 columns, 203758 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.464e+05
#  Factor NZ  : 6.400e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.429e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.27141462e+08 -7.71602795e+07  9.19e+01 0.00e+00  3.22e+03     0s
#    1   5.22928383e+07 -3.48890182e+07  3.18e+01 1.71e-13  8.75e+02     0s
#    2   5.51214886e+06 -7.71657957e+06  3.25e+00 1.71e-13  1.07e+02     0s
#    3   1.03091579e+06 -2.52788617e+06  5.98e-01 1.71e-13  2.60e+01     0s
#    4   8.62724757e+04 -2.72103687e+05  4.84e-02 1.71e-13  2.50e+00     0s
#    5   2.30716807e+03 -2.24626536e+04  9.97e-04 1.71e-13  1.72e-01     0s
#    6   1.74125758e-02 -2.32747960e+00  6.05e-10 2.27e-13  1.63e-05     0s
#
# Barrier performed 6 iterations in 0.49 seconds (0.41 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 24613 iterations and 0.51 seconds (0.52 work units)
# Optimal objective  0.000000000e+00
# 100
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2022.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp1qh9ucy3.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xb6f7442c
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-14, 3e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 93344 rows and 55695 columns
# Presolve time: 0.17s
# Presolved: 64339 rows, 84465 columns, 203810 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.465e+05
#  Factor NZ  : 6.371e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.359e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.26891463e+08 -7.71189654e+07  9.16e+01 0.00e+00  3.22e+03     0s
#    1   5.22001457e+07 -3.49233295e+07  3.17e+01 1.71e-13  8.74e+02     0s
#    2   5.28487040e+06 -8.15981995e+06  3.09e+00 1.71e-13  1.08e+02     0s
#    3   9.98730951e+05 -1.93877715e+06  5.75e-01 1.71e-13  2.14e+01     0s
#    4   1.63278111e+05 -3.57185188e+05  8.80e-02 1.71e-13  3.64e+00     0s
#    5   1.03433336e+04 -3.70687554e+04  5.37e-03 2.27e-13  3.29e-01     0s
#
# Barrier performed 5 iterations in 0.47 seconds (0.38 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Solved in 28193 iterations and 0.47 seconds (0.66 work units)
# Optimal objective  0.000000000e+00
# 121
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2018.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpftnfm63_.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x1269dfcb
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 95446 rows and 55661 columns
# Presolve time: 0.17s
# Presolved: 62237 rows, 84499 columns, 199746 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.382e+05
#  Factor NZ  : 6.462e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.905e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.13111827e+08 -9.19193021e+07  7.68e+01 0.00e+00  2.94e+03     0s
#    1   4.43079034e+07 -2.93095831e+07  2.46e+01 1.71e-13  7.10e+02     0s
#    2   3.05217051e+06 -5.78135494e+06  1.76e+00 3.69e-13  6.93e+01     0s
#    3   6.14688960e+05 -1.43519602e+06  3.60e-01 1.71e-13  1.50e+01     0s
#
# Barrier performed 3 iterations in 0.42 seconds (0.34 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20485 iterations and 0.47 seconds (0.44 work units)
# Optimal objective  0.000000000e+00
# 122
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2019.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmplo9y_mz8.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x078edeba
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-05, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 95505 rows and 55662 columns
# Presolve time: 0.17s
# Presolved: 62178 rows, 84498 columns, 199606 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.379e+05
#  Factor NZ  : 6.481e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.972e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.13050836e+08 -9.20125093e+07  7.66e+01 0.00e+00  2.94e+03     0s
#    1   4.43102178e+07 -2.91877679e+07  2.45e+01 1.71e-13  7.09e+02     0s
#    2   4.82697410e+06 -5.33745414e+06  2.57e+00 3.41e-13  8.19e+01     0s
#    3   6.51635358e+05 -1.33732666e+06  3.45e-01 1.71e-13  1.46e+01     0s
#    4   5.75833598e+03 -9.81645693e+04  2.17e-03 1.71e-13  7.32e-01     0s
#
# Barrier performed 4 iterations in 0.45 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20859 iterations and 0.45 seconds (0.44 work units)
# Optimal objective  0.000000000e+00
# 123
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2020.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpvo3i3z71.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x9c53d28e
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e-05, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 95471 rows and 55665 columns
# Presolve time: 0.18s
# Presolved: 62212 rows, 84495 columns, 199704 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.381e+05
#  Factor NZ  : 6.481e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.952e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.13157040e+08 -9.18863435e+07  7.69e+01 0.00e+00  2.94e+03     0s
#    1   4.41253136e+07 -2.95065595e+07  2.45e+01 1.71e-13  7.09e+02     0s
#    2   2.96202622e+06 -5.85944481e+06  1.72e+00 3.69e-13  6.89e+01     0s
#    3   1.51291450e+05 -8.09989082e+05  8.30e-02 1.71e-13  6.85e+00     0s
#
# Barrier performed 3 iterations in 0.42 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 19595 iterations and 0.44 seconds (0.42 work units)
# Optimal objective  0.000000000e+00
# 124
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2021.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpdid8cy1k.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x2d0bc830
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-06, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 95376 rows and 55653 columns
# Presolve time: 0.17s
# Presolved: 62307 rows, 84507 columns, 199886 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.385e+05
#  Factor NZ  : 6.473e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.931e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.12478167e+08 -9.17321105e+07  7.64e+01 0.00e+00  2.92e+03     0s
#    1   4.38533520e+07 -2.94062985e+07  2.44e+01 2.27e-13  7.05e+02     0s
#    2   3.38328102e+06 -5.83430756e+06  1.96e+00 3.13e-13  7.26e+01     0s
#    3   3.10962508e+05 -1.01033909e+06  1.75e-01 1.71e-13  9.50e+00     0s
#    4   6.11322329e+02 -1.79842025e+04  3.55e-13 2.27e-13  1.31e-01     0s
#
# Barrier performed 4 iterations in 0.45 seconds (0.37 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20197 iterations and 0.46 seconds (0.51 work units)
# Optimal objective  0.000000000e+00
# 125
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2022.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpyyae3ij0.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x70d749e3
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-05, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 95271 rows and 55661 columns
# Presolve time: 0.17s
# Presolved: 62412 rows, 84499 columns, 200080 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.389e+05
#  Factor NZ  : 6.449e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.854e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.12098869e+08 -9.15437287e+07  7.62e+01 0.00e+00  2.91e+03     0s
#    1   4.37356724e+07 -2.95256130e+07  2.44e+01 1.71e-13  7.03e+02     0s
#    2   3.47783242e+06 -5.90345957e+06  2.01e+00 3.41e-13  7.38e+01     0s
#    3   7.67334028e+05 -1.19805286e+06  4.39e-01 1.71e-13  1.44e+01     0s
#    4   2.47518563e+05 -1.95661644e+05  1.38e-01 1.71e-13  3.15e+00     0s
#
# Barrier performed 4 iterations in 0.46 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20131 iterations and 0.47 seconds (0.44 work units)
# Optimal objective  2.530652864e+03

# %%
# Initialize a dictionary to store averaged results
testing_averaged_results = {}

# Iterate over each location
for location, years_data in testing_results.items():
    # Initialize a dictionary to store sums and counts for averaging
    sums = {
        'Total Cost': 0,
        'Capital Cost': 0,
        'Operation Cost': 0
    }
    count = 0

    # Iterate over each year for the location
    for year, data in years_data.items():
        for key in sums:
            sums[key] += data[key]
        count += 1

    # Calculate averages
    testing_averaged_results[location] = {key: value / count for key, value in sums.items()}

# Print the averaged results
print(testing_averaged_results)
# Out:
# {'Arizona': {'Total Cost': 23208.200999999997, 'Capital Cost': 22877.555, 'Operation Cost': 330.646}, 'Alaska': {'Total Cost': 43853.054, 'Capital Cost': 43853.054, 'Operation Cost': 0.0}, 'Minnesota': {'Total Cost': 31718.2038, 'Capital Cost': 30662.716000000004, 'Operation Cost': 1055.4878}, 'Florida': {'Total Cost': 20814.998, 'Capital Cost': 20814.998, 'Operation Cost': 0.0}, 'HalfMoonBay': {'Total Cost': 21667.8956, 'Capital Cost': 21161.765, 'Operation Cost': 506.13059999999996}}

# %%
from pathlib import Path

# Define the output file path
output_file = "Results_SA_Location_SO.xlsx"

# Store Training Result
train_df = pd.DataFrame(training_results).T 
sheet_name_train = "Training Results"

# Check if the file exists
if not Path(output_file).exists():
    # If the file does not exist, create it
    with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
        train_df.to_excel(writer, sheet_name=sheet_name_train)
    print(f"File '{output_file}' created with sheet '{sheet_name_train}'.")
else:
    # If the file exists, append the new sheet
    with pd.ExcelWriter(output_file, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
        train_df.to_excel(writer, sheet_name=sheet_name_train)
    print(f"Data written to '{output_file}' in sheet '{sheet_name_train}'.")


# Store Testing Result
test_df = pd.DataFrame(testing_averaged_results).T 
sheet_name_test = "Testing Results"

# Check if the file exists
if not Path(output_file).exists():
    # If the file does not exist, create it
    with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
        test_df.to_excel(writer, sheet_name=sheet_name_test)
    print(f"File '{output_file}' created with sheet '{sheet_name_test}'.")
else:
    # If the file exists, append the new sheet
    with pd.ExcelWriter(output_file, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
        test_df.to_excel(writer, sheet_name=sheet_name_test)
    print(f"Data written to '{output_file}' in sheet '{sheet_name_test}'.")
# Out:
# Data written to 'Results_SA_Location_SO.xlsx' in sheet 'Training Results'.
# Data written to 'Results_SA_Location_SO.xlsx' in sheet 'Testing Results'.
