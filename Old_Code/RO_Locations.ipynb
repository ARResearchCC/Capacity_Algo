# %%
import Data_Conversion
import Input_Parameters 
import Data_Conversion
import Passive_Model
import Solar_Generation
import Electrical_Load
import RO
# Out:
# /Users/jimmy/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
import numpy as np
import pandas as pd

# %%
# Sensitivity Analysis on Locations, Stochastic Optimization
# Fred Fan, Stanford University, 03/17/2025

# %%
# Define the base data directory, list of locations, and the weather year.
data_dir = "Data"
locations = ["Arizona", 
             "Alaska", 
             "Minnesota", 
             "Florida", 
             "HalfMoonBay"]

# 20 years of training data
weather_year_list_training = list(range(1998, 2018))  # use list(range(1998, 2018)) for full dataset
# 5 years of training data
weather_year_list_testing = list(range(2018, 2023))  # use list(range(2018, 2023)) for full dataset

# Set a random seed for consistency
# Define the number of rows (i) and columns (j)
i = len(locations)  # Number of rows
j = len(weather_year_list_training) + len(weather_year_list_testing)  # Number of columns

# Generate a sequential array of numbers starting from 1
total_cells = i * j  # Total number of cells in the DataFrame
sequential_numbers = np.arange(1, total_cells + 1)  # Generates 1, 2, 3, ..., i*j

# Reshape the array into a 2D array with i rows and j columns
data = sequential_numbers.reshape(i, j)

# Convert the array into a DataFrame
random_seeds = pd.DataFrame(data, columns=[f'Column_{k+1}' for k in range(j)])

lats, lons, timezones = Data_Conversion.get_timezones(data_dir, locations)
# Out:
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_1998.csv
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_1998.csv
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_1998.csv
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_1998.csv
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_1998.csv

# %%
# Create dictionary for recording results
training_results = {}  # Initialize as an empty dictionary

# %%
len(weather_year_list_training)
# Out:
# 20

# %%
# Sensitivity Analysis on Locations

for i in range(len(locations)):
    # Initialize storing space to store all input_dfs
    input_df_list_train = []

    for j in range(len(weather_year_list_training)):
        
        location = locations[i]
        year = weather_year_list_training[j]

        # Get a unique random seed number
        random_seed = random_seeds.iloc[i, j]
        print(random_seed)
        
        # Read NSRDB weather data of the given location of the given year
        NSRDB_raw_weather = Data_Conversion.read_NSRDB(data_dir, location, year)

        # Prepare weather data file using NSRDB data
        weather_data = Data_Conversion.prepare_NSRDB(NSRDB_raw_weather, lats[i], lons[i], timezones[i])

        # Prepare heating and cooling load using weather data and passive model
        NetHeatTransfers = Passive_Model.passive_model(Input_Parameters.calibration_file_path, weather_data, Input_Parameters.T_indoor_constant, lats[i])

        # Prepare solar PV capacity factor using weather data
        pv_cf = Solar_Generation.generate_pv(weather_data, lats[i])

        # Prepare occupancy and electrical load schedule using for a specific random seed number for a specific year at a specific location
        load_sched = Electrical_Load.generate_schedules("bayes", weather_data, random_seed)
        
        # Combine all relative input data as input_df, which will be the input of the capacity optimization algorithm
        input_df = Data_Conversion.combine_input_NSRDB(weather_data, load_sched, pv_cf, NetHeatTransfers)
        
        # Add input_df to list
        input_df_list_train.append(input_df)

    PV_Size, Battery_Size, PCM_Heating_Size, PCM_Cooling_Size, ObjValue, First_stage_cost, Second_stage_cost = RO.RO_training(input_df_list_train, Input_Parameters.lossofloadcost)

    # Store the variables in the nested dictionary
    training_results[location] = {
        'PV_Size': PV_Size,
        'Battery_Size': Battery_Size,
        'PCM_Heating_Size': PCM_Heating_Size,
        'PCM_Cooling_Size': PCM_Cooling_Size,
        'Total Cost': ObjValue,
        'Capital Cost': First_stage_cost,
        'Operation Cost': Second_stage_cost
    }
# Out:
# 1
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_1998.csv
# 2
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_1999.csv
# 3
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2000.csv
# 4
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2001.csv
# 5
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2002.csv
# 6
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2003.csv
# 7
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2004.csv
# 8
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2005.csv
# 9
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2006.csv
# 10
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2007.csv
# 11
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2008.csv
# 12
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2009.csv
# 13
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2010.csv
# 14
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2011.csv
# 15
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2012.csv
# 16
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2013.csv
# 17
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2014.csv
# 18
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2015.csv
# 19
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2016.csv
# 20
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2017.csv
# Starting robust optimization algorithm...
#
# --- Iteration 1 ---
# Adding cut for scenario 8 with cost 125211.89
# Current solution:
#   PV Size: 21.87 kW
#   Battery Size: 18.43 kWh
#   PCM Heating Size: 46.55 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 21160.63
#   Total cost: 22860.37
#   Lower Bound: 22860.37, Upper Bound: 146372.52
#   Optimality gap: 84.38%
#   Maximum capacity change: 41.551078
#
# --- Iteration 2 ---
# Adding cut for scenario 13 with cost 5177.84
# Current solution:
#   PV Size: 12.83 kW
#   Battery Size: 18.43 kWh
#   PCM Heating Size: 74.30 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 22860.37
#   Total cost: 22887.98
#   Lower Bound: 22887.98, Upper Bound: 28038.20
#   Optimality gap: 18.37%
#   Maximum capacity change: 27.746418
#
# --- Iteration 3 ---
# Adding cut for scenario 17 with cost 5347.51
# Current solution:
#   PV Size: 16.52 kW
#   Battery Size: 18.43 kWh
#   PCM Heating Size: 74.30 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 22887.98
#   Total cost: 23173.17
#   Lower Bound: 23173.17, Upper Bound: 28038.20
#   Optimality gap: 17.35%
#   Maximum capacity change: 3.693502
#
# --- Iteration 4 ---
# Adding cut for scenario 9 with cost 213.66
# Current solution:
#   PV Size: 16.52 kW
#   Battery Size: 18.71 kWh
#   PCM Heating Size: 73.65 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 23173.17
#   Total cost: 23186.73
#   Lower Bound: 23186.73, Upper Bound: 23386.83
#   Optimality gap: 0.86%
#   Maximum capacity change: 0.642962
#
# --- Iteration 5 ---
# Adding cut for scenario 0 with cost 0.00
# Current solution:
#   PV Size: 16.52 kW
#   Battery Size: 18.71 kWh
#   PCM Heating Size: 73.65 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 23186.73
#   Total cost: 23186.73
#   Lower Bound: 23186.73, Upper Bound: 23186.73
#   Optimality gap: 0.00%
#
# Algorithm converged based on optimality gap!
# 26
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_1998.csv
# 27
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_1999.csv
# 28
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2000.csv
# 29
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2001.csv
# 30
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2002.csv
# 31
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2003.csv
# 32
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2004.csv
# 33
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2005.csv
# 34
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2006.csv
# 35
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2007.csv
# 36
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2008.csv
# 37
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2009.csv
# 38
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2010.csv
# 39
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2011.csv
# 40
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2012.csv
# 41
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2013.csv
# 42
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2014.csv
# 43
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2015.csv
# 44
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2016.csv
# 45
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2017.csv
# Starting robust optimization algorithm...
#
# --- Iteration 1 ---
# Adding cut for scenario 1 with cost 5753186.72
# Current solution:
#   PV Size: 201.31 kW
#   Battery Size: 31.45 kWh
#   PCM Heating Size: 344.41 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 21160.63
#   Total cost: 45950.36
#   Lower Bound: 45950.36, Upper Bound: 5774347.35
#   Optimality gap: 99.20%
#   Maximum capacity change: 339.412472
#
# --- Iteration 2 ---
# Adding cut for scenario 15 with cost 6816.08
# Current solution:
#   PV Size: 205.73 kW
#   Battery Size: 29.97 kWh
#   PCM Heating Size: 340.55 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 45950.36
#   Total cost: 46025.82
#   Lower Bound: 46025.82, Upper Bound: 52766.44
#   Optimality gap: 12.77%
#   Maximum capacity change: 4.420532
#
# --- Iteration 3 ---
# Adding cut for scenario 2 with cost 2230.93
# Current solution:
#   PV Size: 206.61 kW
#   Battery Size: 30.53 kWh
#   PCM Heating Size: 337.77 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 46025.82
#   Total cost: 46083.67
#   Lower Bound: 46083.67, Upper Bound: 48256.75
#   Optimality gap: 4.50%
#   Maximum capacity change: 2.778396
#
# --- Iteration 4 ---
# Adding cut for scenario 0 with cost 0.00
# Current solution:
#   PV Size: 206.61 kW
#   Battery Size: 30.53 kWh
#   PCM Heating Size: 337.77 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 46083.67
#   Total cost: 46083.67
#   Lower Bound: 46083.67, Upper Bound: 46083.67
#   Optimality gap: -0.00%
#
# Algorithm converged based on optimality gap!
# 51
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_1998.csv
# 52
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_1999.csv
# 53
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2000.csv
# 54
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2001.csv
# 55
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2002.csv
# 56
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2003.csv
# 57
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2004.csv
# 58
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2005.csv
# 59
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2006.csv
# 60
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2007.csv
# 61
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2008.csv
# 62
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2009.csv
# 63
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2010.csv
# 64
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2011.csv
# 65
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2012.csv
# 66
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2013.csv
# 67
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2014.csv
# 68
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2015.csv
# 69
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2016.csv
# 70
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2017.csv
# Starting robust optimization algorithm...
#
# --- Iteration 1 ---
# Adding cut for scenario 16 with cost 3090829.63
# Current solution:
#   PV Size: 60.26 kW
#   Battery Size: 10.29 kWh
#   PCM Heating Size: 185.03 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 21160.63
#   Total cost: 28546.79
#   Lower Bound: 28546.79, Upper Bound: 3111990.26
#   Optimality gap: 99.08%
#   Maximum capacity change: 180.027932
#
# --- Iteration 2 ---
# Adding cut for scenario 11 with cost 83304.76
# Current solution:
#   PV Size: 121.35 kW
#   Battery Size: 10.29 kWh
#   PCM Heating Size: 179.26 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 28546.79
#   Total cost: 33113.21
#   Lower Bound: 33113.21, Upper Bound: 111851.55
#   Optimality gap: 70.40%
#   Maximum capacity change: 61.093281
#
# --- Iteration 3 ---
# Adding cut for scenario 3 with cost 6976.67
# Current solution:
#   PV Size: 120.43 kW
#   Battery Size: 14.33 kWh
#   PCM Heating Size: 169.79 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 33113.21
#   Total cost: 33241.08
#   Lower Bound: 33241.08, Upper Bound: 40089.89
#   Optimality gap: 17.08%
#   Maximum capacity change: 9.464234
#
# --- Iteration 4 ---
# Adding cut for scenario 8 with cost 856.54
# Current solution:
#   PV Size: 120.19 kW
#   Battery Size: 15.42 kWh
#   PCM Heating Size: 167.22 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 33241.08
#   Total cost: 33276.02
#   Lower Bound: 33276.02, Upper Bound: 34097.61
#   Optimality gap: 2.41%
#   Maximum capacity change: 2.574866
#
# --- Iteration 5 ---
# Adding cut for scenario 0 with cost 0.00
# Current solution:
#   PV Size: 120.19 kW
#   Battery Size: 15.42 kWh
#   PCM Heating Size: 167.22 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 33276.02
#   Total cost: 33276.02
#   Lower Bound: 33276.02, Upper Bound: 33276.02
#   Optimality gap: 0.00%
#
# Algorithm converged based on optimality gap!
# 76
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_1998.csv
# 77
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_1999.csv
# 78
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2000.csv
# 79
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2001.csv
# 80
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2002.csv
# 81
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2003.csv
# 82
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2004.csv
# 83
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2005.csv
# 84
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2006.csv
# 85
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2007.csv
# 86
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2008.csv
# 87
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2009.csv
# 88
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2010.csv
# 89
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2011.csv
# 90
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2012.csv
# 91
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2013.csv
# 92
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2014.csv
# 93
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2015.csv
# 94
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2016.csv
# 95
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2017.csv
# Starting robust optimization algorithm...
#
# --- Iteration 1 ---
# Adding cut for scenario 18 with cost 4979.16
# Current solution:
#   PV Size: 5.09 kW
#   Battery Size: 5.44 kWh
#   PCM Heating Size: 0.00 kWh
#   PCM Cooling Size: 54.52 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 21160.63
#   Total cost: 20335.16
#   Lower Bound: 20335.16, Upper Bound: 26139.79
#   Optimality gap: 22.21%
#   Maximum capacity change: 49.515614
#
# --- Iteration 2 ---
# Adding cut for scenario 12 with cost 38846.76
# Current solution:
#   PV Size: 7.02 kW
#   Battery Size: 14.56 kWh
#   PCM Heating Size: 0.00 kWh
#   PCM Cooling Size: 27.42 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 20335.16
#   Total cost: 20785.11
#   Lower Bound: 20785.11, Upper Bound: 26139.79
#   Optimality gap: 20.48%
#   Maximum capacity change: 27.092524
#
# --- Iteration 3 ---
# Adding cut for scenario 11 with cost 1215.45
# Current solution:
#   PV Size: 6.29 kW
#   Battery Size: 15.01 kWh
#   PCM Heating Size: 0.00 kWh
#   PCM Cooling Size: 29.81 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 20785.11
#   Total cost: 20840.23
#   Lower Bound: 20840.23, Upper Bound: 22000.56
#   Optimality gap: 5.27%
#   Maximum capacity change: 2.391283
#
# --- Iteration 4 ---
# Adding cut for scenario 0 with cost 1597.10
# Current solution:
#   PV Size: 6.71 kW
#   Battery Size: 14.74 kWh
#   PCM Heating Size: 0.00 kWh
#   PCM Cooling Size: 30.27 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 20840.23
#   Total cost: 20855.38
#   Lower Bound: 20855.38, Upper Bound: 22000.56
#   Optimality gap: 5.21%
#   Maximum capacity change: 0.455976
#
# --- Iteration 5 ---
# Current solution:
#   PV Size: 6.71 kW
#   Battery Size: 14.74 kWh
#   PCM Heating Size: 0.00 kWh
#   PCM Cooling Size: 30.27 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 20855.38
#   Total cost: 20855.38
#   Lower Bound: 20855.38, Upper Bound: 20855.38
#   Optimality gap: 0.00%
#
# Algorithm converged based on optimality gap!
# 101
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_1998.csv
# 102
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_1999.csv
# 103
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2000.csv
# 104
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2001.csv
# 105
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2002.csv
# 106
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2003.csv
# 107
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2004.csv
# 108
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2005.csv
# 109
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2006.csv
# 110
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2007.csv
# 111
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2008.csv
# 112
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2009.csv
# 113
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2010.csv
# 114
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2011.csv
# 115
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2012.csv
# 116
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2013.csv
# 117
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2014.csv
# 118
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2015.csv
# 119
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2016.csv
# 120
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2017.csv
# Starting robust optimization algorithm...
#
# --- Iteration 1 ---
# Adding cut for scenario 11 with cost 13200.55
# Current solution:
#   PV Size: 11.52 kW
#   Battery Size: 2.27 kWh
#   PCM Heating Size: 73.45 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 21160.63
#   Total cost: 20975.90
#   Lower Bound: 20975.90, Upper Bound: 34361.19
#   Optimality gap: 38.95%
#   Maximum capacity change: 68.449977
#
# --- Iteration 2 ---
# Adding cut for scenario 16 with cost 25653.58
# Current solution:
#   PV Size: 11.52 kW
#   Battery Size: 6.54 kWh
#   PCM Heating Size: 60.13 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 20975.90
#   Total cost: 21100.06
#   Lower Bound: 21100.06, Upper Bound: 34361.19
#   Optimality gap: 38.59%
#   Maximum capacity change: 13.318902
#
# --- Iteration 3 ---
# Adding cut for scenario 6 with cost 3184.38
# Current solution:
#   PV Size: 22.00 kW
#   Battery Size: 6.54 kWh
#   PCM Heating Size: 39.75 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 21100.06
#   Total cost: 21376.50
#   Lower Bound: 21376.50, Upper Bound: 24284.44
#   Optimality gap: 11.97%
#   Maximum capacity change: 20.378687
#
# --- Iteration 4 ---
# Adding cut for scenario 0 with cost 12497.07
# Current solution:
#   PV Size: 18.21 kW
#   Battery Size: 6.54 kWh
#   PCM Heating Size: 52.83 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 21376.50
#   Total cost: 21425.95
#   Lower Bound: 21425.95, Upper Bound: 24284.44
#   Optimality gap: 11.77%
#   Maximum capacity change: 13.080624
#
# --- Iteration 5 ---
# Adding cut for scenario 10 with cost 780.81
# Current solution:
#   PV Size: 15.72 kW
#   Battery Size: 6.54 kWh
#   PCM Heating Size: 61.44 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 21425.95
#   Total cost: 21458.52
#   Lower Bound: 21458.52, Upper Bound: 22206.76
#   Optimality gap: 3.37%
#   Maximum capacity change: 8.611591
#
# --- Iteration 6 ---
# Current solution:
#   PV Size: 15.72 kW
#   Battery Size: 6.54 kWh
#   PCM Heating Size: 61.44 kWh
#   PCM Cooling Size: 0.00 kWh
#   Worst-case operational cost: 0.00
#   First-stage cost: 21458.52
#   Total cost: 21458.52
#   Lower Bound: 21458.52, Upper Bound: 21458.52
#   Optimality gap: 0.00%
#
# Algorithm converged based on optimality gap!

# %%
print(training_results)
# Out:
# {'Arizona': {'PV_Size': 16.522, 'Battery_Size': 18.708, 'PCM_Heating_Size': 73.655, 'PCM_Cooling_Size': 0.0, 'Total Cost': 23186.777, 'Capital Cost': 23186.777, 'Operation Cost': 0.0}, 'Alaska': {'PV_Size': 206.614, 'Battery_Size': 30.532, 'PCM_Heating_Size': 337.768, 'PCM_Cooling_Size': 0.0, 'Total Cost': 46083.736, 'Capital Cost': 46083.736, 'Operation Cost': 0.0}, 'Minnesota': {'PV_Size': 120.186, 'Battery_Size': 15.424, 'PCM_Heating_Size': 167.22, 'PCM_Cooling_Size': 0.0, 'Total Cost': 33275.964, 'Capital Cost': 33275.964, 'Operation Cost': 0.0}, 'Florida': {'PV_Size': 6.711, 'Battery_Size': 14.744, 'PCM_Heating_Size': 0.0, 'PCM_Cooling_Size': 30.27, 'Total Cost': 20855.406, 'Capital Cost': 20855.406, 'Operation Cost': 0.0}, 'HalfMoonBay': {'PV_Size': 15.716, 'Battery_Size': 6.54, 'PCM_Heating_Size': 61.445, 'PCM_Cooling_Size': 0.0, 'Total Cost': 21458.573, 'Capital Cost': 21458.573, 'Operation Cost': 0.0}}

# %%
# Testing:

# Create the nested dictionary
testing_results = {location: {year: {} for year in weather_year_list_testing} for location in locations}

for i in range(len(locations)):
    location = locations[i]
    test_capacities = [training_results[location]['PV_Size'], training_results[location]['Battery_Size'], training_results[location]['PCM_Heating_Size'], training_results[location]['PCM_Cooling_Size']]
    for j in range(len(weather_year_list_testing)):
        year = weather_year_list_testing[j]
        
        # Get a unique random seed number
        random_seed = random_seeds.iloc[i, j+len(weather_year_list_training)]
        print(random_seed)
        
        # Read NSRDB weather data of the given location of the given year
        NSRDB_raw_weather = Data_Conversion.read_NSRDB(data_dir, location, year)

        # Prepare weather data file using NSRDB data
        weather_data = Data_Conversion.prepare_NSRDB(NSRDB_raw_weather, lats[i], lons[i], timezones[i])

        # Prepare heating and cooling load using weather data and passive model
        NetHeatTransfers = Passive_Model.passive_model(Input_Parameters.calibration_file_path, weather_data, Input_Parameters.T_indoor_constant, lats[i])

        # Prepare solar PV capacity factor using weather data
        pv_cf = Solar_Generation.generate_pv(weather_data, lats[i])

        # Prepare occupancy and electrical load schedule using for a specific random seed number for a specific year at a specific location
        load_sched = Electrical_Load.generate_schedules("bayes", weather_data, random_seed)
        
        # Combine all relative input data as input_df, which will be the input of the capacity optimization algorithm
        input_df = Data_Conversion.combine_input_NSRDB(weather_data, load_sched, pv_cf, NetHeatTransfers)
    
        ObjValue, First_stage_cost, Second_stage_cost = RO.simulate(input_df, Input_Parameters.lossofloadcost, test_capacities)
        # Store the variables in the nested dictionary
        testing_results[location][year] = {
            'Total Cost': ObjValue,
            'Capital Cost': First_stage_cost,
            'Operation Cost': Second_stage_cost
        }
# Out:
# 21
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2018.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmppspz7s7a.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xa1bca112
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-04, 1e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 92020 rows and 55756 columns
# Presolve time: 0.17s
# Presolved: 65663 rows, 84404 columns, 206030 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.513e+05
#  Factor NZ  : 6.244e+05 (roughly 70 MB of memory)
#  Factor Ops : 6.944e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.58333798e+08 -1.02945587e+08  1.28e+02 0.00e+00  4.08e+03     0s
#    1   6.01735847e+07 -4.90704629e+07  4.26e+01 1.71e-13  1.07e+03     0s
#    2   1.09149525e+07 -1.36333902e+07  7.13e+00 1.01e-11  1.97e+02     0s
#    3   1.06071478e+06 -3.28604831e+06  7.63e-01 1.89e-12  3.10e+01     0s
#    4   2.26400797e+05 -3.03687979e+05  1.57e-01 6.68e-13  3.68e+00     0s
#
# Barrier performed 4 iterations in 0.41 seconds (0.37 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20733 iterations and 0.42 seconds (0.39 work units)
# Optimal objective  0.000000000e+00
# 22
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2019.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmphhw58n9c.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xbc461a3a
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e-05, 1e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 92012 rows and 55737 columns
# Presolve time: 0.17s
# Presolved: 65671 rows, 84423 columns, 206056 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.513e+05
#  Factor NZ  : 6.245e+05 (roughly 70 MB of memory)
#  Factor Ops : 6.949e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.57976441e+08 -1.02890752e+08  1.28e+02 0.00e+00  4.07e+03     0s
#    1   6.01664018e+07 -4.89407168e+07  4.26e+01 2.27e-13  1.07e+03     0s
#    2   9.40893141e+06 -1.28340451e+07  6.32e+00 1.11e-11  1.77e+02     0s
#    3   7.00665795e+05 -2.96006150e+06  5.14e-01 2.16e-12  2.59e+01     0s
#    4   3.14227854e+04 -1.11563192e+05  2.16e-02 3.06e-13  9.84e-01     0s
#
# Barrier performed 4 iterations in 0.40 seconds (0.37 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20863 iterations and 0.40 seconds (0.40 work units)
# Optimal objective  0.000000000e+00
# 23
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2020.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpe40am3x2.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xebad4894
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-13, 1e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 92019 rows and 55753 columns
# Presolve time: 0.17s
# Presolved: 65664 rows, 84407 columns, 206028 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.513e+05
#  Factor NZ  : 6.244e+05 (roughly 70 MB of memory)
#  Factor Ops : 6.944e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.57831628e+08 -1.02877915e+08  1.28e+02 0.00e+00  4.07e+03     0s
#    1   5.96869701e+07 -4.90335697e+07  4.22e+01 1.71e-13  1.06e+03     0s
#    2   1.06644154e+07 -1.35410943e+07  6.98e+00 1.13e-11  1.93e+02     0s
#    3   8.56430001e+05 -3.13155045e+06  6.01e-01 8.67e-13  2.83e+01     0s
#    4   2.58480431e+04 -8.77256022e+04  1.71e-02 2.04e-13  7.82e-01     0s
#
# Barrier performed 4 iterations in 0.39 seconds (0.37 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20920 iterations and 0.40 seconds (0.39 work units)
# Optimal objective  0.000000000e+00
# 24
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2021.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp133w999d.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x769b2a02
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-04, 2e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 92024 rows and 55754 columns
# Presolve time: 0.17s
# Presolved: 65659 rows, 84406 columns, 206036 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.513e+05
#  Factor NZ  : 6.243e+05 (roughly 70 MB of memory)
#  Factor Ops : 6.942e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.58979034e+08 -1.03004193e+08  1.29e+02 0.00e+00  4.10e+03     0s
#    1   6.03377946e+07 -4.93432116e+07  4.28e+01 2.27e-13  1.08e+03     0s
#    2   1.08451261e+07 -1.36248346e+07  7.09e+00 6.14e-12  1.96e+02     0s
#    3   7.01055465e+05 -2.44118367e+06  4.71e-01 1.88e-12  2.22e+01     0s
#    4   2.31286656e+04 -7.07738842e+04  1.36e-02 2.27e-13  6.46e-01     0s
#    5   9.84810370e-01 -3.33043314e+01  4.41e-07 2.27e-13  2.36e-04     0s
#
# Barrier performed 5 iterations in 0.42 seconds (0.39 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20797 iterations and 0.42 seconds (0.40 work units)
# Optimal objective  0.000000000e+00
# 25
# Reading file for Arizona: Data/NREL_NSRDB_Arizona/323705_33.45_-112.06_2022.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpdszdna36.pyomo.lp
# Reading time = 0.29 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xa5d206b5
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-14, 1e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 92010 rows and 55752 columns
# Presolve time: 0.17s
# Presolved: 65673 rows, 84408 columns, 206070 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.513e+05
#  Factor NZ  : 6.245e+05 (roughly 70 MB of memory)
#  Factor Ops : 6.946e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.61381573e+08 -1.02898631e+08  1.32e+02 0.00e+00  4.15e+03     0s
#    1   6.08976111e+07 -5.01494256e+07  4.34e+01 1.71e-13  1.09e+03     0s
#    2   1.15656258e+07 -1.40611199e+07  7.61e+00 1.58e-11  2.06e+02     0s
#    3   1.27692835e+06 -3.43931096e+06  9.09e-01 1.53e-12  3.38e+01     0s
#    4   1.42588098e+05 -1.57018575e+05  9.86e-02 3.80e-13  2.07e+00     0s
#
# Barrier performed 4 iterations in 0.38 seconds (0.37 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20516 iterations and 0.41 seconds (0.39 work units)
# Optimal objective  1.086513864e+03
# 46
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2018.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmph4h9ocol.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x7e82dcbd
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-03, 2e+08]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 94398 rows and 60498 columns
# Presolve time: 0.17s
# Presolved: 63285 rows, 79662 columns, 197435 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.460e+05
#  Factor NZ  : 6.387e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.585e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.74893106e+08 -2.37235427e+08  4.44e+02 0.00e+00  8.46e+03     0s
#    1   9.08668585e+07 -8.27853442e+07  1.33e+02 2.27e-13  1.97e+03     0s
#    2   1.17892392e+07 -2.44008833e+07  1.51e+01 3.18e-12  3.01e+02     0s
#    3   2.23040035e+06 -5.50881650e+06  2.93e+00 1.09e-12  5.79e+01     0s
#
# Barrier performed 3 iterations in 0.38 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 15789 iterations and 0.38 seconds (0.41 work units)
# Optimal objective  0.000000000e+00
# 47
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2019.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmprfv28qv3.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x6458e3ee
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-03, 1e+08]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 94580 rows and 61231 columns
# Presolve time: 0.17s
# Presolved: 63103 rows, 78929 columns, 196087 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.449e+05
#  Factor NZ  : 6.508e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.919e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.53237609e+08 -2.28202107e+08  4.06e+02 0.00e+00  8.08e+03     0s
#    1   8.42525574e+07 -8.00703635e+07  1.23e+02 1.71e-13  1.89e+03     0s
#    2   1.05209178e+07 -2.42391988e+07  1.36e+01 5.83e-12  2.89e+02     0s
#    3   1.41086925e+06 -4.97240340e+06  1.86e+00 8.38e-13  4.72e+01     0s
#
# Barrier performed 3 iterations in 0.39 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 14137 iterations and 0.39 seconds (0.44 work units)
# Optimal objective  0.000000000e+00
# 48
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2020.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp857eylfl.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x5ca49d78
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-03, 1e+08]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 94674 rows and 61427 columns
# Presolve time: 0.17s
# Presolved: 63009 rows, 78733 columns, 195717 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.447e+05
#  Factor NZ  : 6.508e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.934e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.45954970e+08 -2.25264753e+08  4.01e+02 0.00e+00  7.90e+03     0s
#    1   8.08907810e+07 -7.85725090e+07  1.20e+02 1.71e-13  1.83e+03     0s
#    2   1.10128652e+07 -2.33209263e+07  1.48e+01 4.77e-12  2.89e+02     0s
#    3   1.22685609e+06 -4.13704821e+06  1.69e+00 1.02e-12  3.97e+01     0s
#
# Barrier performed 3 iterations in 0.36 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 14809 iterations and 0.37 seconds (0.38 work units)
# Optimal objective  0.000000000e+00
# 49
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2021.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpj_w2r55s.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xe362b726
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-04, 1e+08]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 94730 rows and 61560 columns
# Presolve time: 0.17s
# Presolved: 62953 rows, 78600 columns, 195461 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.445e+05
#  Factor NZ  : 6.499e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.912e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.43250624e+08 -2.23955156e+08  4.02e+02 0.00e+00  7.86e+03     0s
#    1   8.03145439e+07 -7.84404797e+07  1.21e+02 2.27e-13  1.83e+03     0s
#    2   1.05544281e+07 -2.37135135e+07  1.44e+01 5.49e-12  2.87e+02     0s
#    3   1.45362149e+06 -4.19968176e+06  2.01e+00 1.17e-12  4.21e+01     0s
#
# Barrier performed 3 iterations in 0.37 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 15018 iterations and 0.37 seconds (0.40 work units)
# Optimal objective  0.000000000e+00
# 50
# Reading file for Alaska: Data/NREL_NSRDB_Alaska/34776_59.25_-154.62_2022.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpn5ap7tti.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x4f250474
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 3e+08]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 94344 rows and 60767 columns
# Presolve time: 0.17s
# Presolved: 63339 rows, 79393 columns, 197017 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.456e+05
#  Factor NZ  : 6.494e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.838e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.54737878e+08 -2.29360015e+08  3.94e+02 0.00e+00  7.98e+03     0s
#    1   8.41974934e+07 -7.89290907e+07  1.19e+02 1.71e-13  1.85e+03     0s
#    2   1.05310744e+07 -2.33514021e+07  1.33e+01 1.34e-11  2.80e+02     0s
#    3   8.32772616e+05 -3.25106077e+06  1.03e+00 1.14e-12  2.98e+01     0s
#
# Barrier performed 3 iterations in 0.36 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 14876 iterations and 0.36 seconds (0.37 work units)
# Optimal objective  0.000000000e+00
# 71
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2018.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpmtkr7n4n.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xe46ca208
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-14, 2e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 93681 rows and 59489 columns
# Presolve time: 0.17s
# Presolved: 64002 rows, 80671 columns, 199500 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.472e+05
#  Factor NZ  : 6.280e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.071e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.33009729e+08 -1.30725497e+08  1.38e+02 0.00e+00  3.91e+03     0s
#    1   5.17957431e+07 -4.16416949e+07  4.85e+01 2.27e-13  9.29e+02     0s
#    2   8.13226165e+06 -1.17224434e+07  7.58e+00 3.44e-12  1.60e+02     0s
#    3   6.59382978e+05 -1.91069227e+06  6.08e-01 8.53e-13  1.86e+01     0s
#    4   4.03125614e+03 -6.37633883e+04  2.40e-03 1.71e-13  4.77e-01     0s
#
# Barrier performed 4 iterations in 0.42 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 19605 iterations and 0.43 seconds (0.44 work units)
# Optimal objective  0.000000000e+00
# 72
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2019.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmph4airqvb.pyomo.lp
# Reading time = 0.29 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xb9c86cb1
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-14, 2e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 93725 rows and 59530 columns
# Presolve time: 0.17s
# Presolved: 63958 rows, 80630 columns, 199382 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.471e+05
#  Factor NZ  : 6.259e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.034e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.36117129e+08 -1.31789790e+08  1.43e+02 0.00e+00  4.01e+03     0s
#    1   5.25970859e+07 -4.30101417e+07  4.96e+01 1.71e-13  9.57e+02     0s
#    2   9.10201654e+06 -1.20306915e+07  8.52e+00 6.57e-12  1.72e+02     0s
#    3   8.78455498e+05 -2.05021797e+06  8.96e-01 1.92e-12  2.15e+01     0s
#    4   3.39654975e+05 -4.26104939e+05  3.68e-01 3.13e-13  5.48e+00     0s
#    5   6.57840292e+03 -5.05942984e+04  6.75e-03 1.71e-13  4.03e-01     0s
#
# Barrier performed 5 iterations in 0.44 seconds (0.38 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 19360 iterations and 0.44 seconds (0.44 work units)
# Optimal objective  0.000000000e+00
# 73
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2020.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpjjadxxz9.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x9f0dc146
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-05, 2e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 93786 rows and 59671 columns
# Presolve time: 0.17s
# Presolved: 63897 rows, 80489 columns, 199114 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.469e+05
#  Factor NZ  : 6.237e+05 (roughly 60 MB of memory)
#  Factor Ops : 6.989e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.36320567e+08 -1.31725087e+08  1.44e+02 0.00e+00  4.04e+03     0s
#    1   5.30584776e+07 -4.34293110e+07  5.06e+01 2.27e-13  9.71e+02     0s
#    2   7.74763214e+06 -1.17869267e+07  7.33e+00 1.69e-11  1.58e+02     0s
#    3   5.66399538e+05 -1.89035754e+06  5.53e-01 9.95e-13  1.78e+01     0s
#    4   1.06138892e+03 -5.13503585e+04  3.44e-12 2.27e-13  3.69e-01     0s
#
# Barrier performed 4 iterations in 0.42 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 19312 iterations and 0.43 seconds (0.43 work units)
# Optimal objective  0.000000000e+00
# 74
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2021.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpby8qxf3i.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xf142cbe2
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-04, 2e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 93878 rows and 59860 columns
# Presolve time: 0.17s
# Presolved: 63805 rows, 80300 columns, 198734 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.466e+05
#  Factor NZ  : 6.243e+05 (roughly 60 MB of memory)
#  Factor Ops : 6.995e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.37619325e+08 -1.32101929e+08  1.48e+02 0.00e+00  4.11e+03     0s
#    1   5.34781310e+07 -4.44318131e+07  5.19e+01 1.71e-13  9.94e+02     0s
#    2   8.66721553e+06 -1.23619182e+07  8.32e+00 1.17e-11  1.72e+02     0s
#    3   3.64411057e+05 -2.03551357e+06  3.62e-01 6.11e-13  1.73e+01     0s
#    4   8.90035841e+02 -2.27337466e+04  1.83e-04 2.27e-13  1.67e-01     0s
#
# Barrier performed 4 iterations in 0.40 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 18905 iterations and 0.42 seconds (0.43 work units)
# Optimal objective  0.000000000e+00
# 75
# Reading file for Minnesota: Data/NREL_NSRDB_Minnesota/777900_44.97_-93.26_2022.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpy7mwqh72.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xdd6234bc
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-14, 2e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 93817 rows and 59680 columns
# Presolve time: 0.17s
# Presolved: 63866 rows, 80480 columns, 199024 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.468e+05
#  Factor NZ  : 6.237e+05 (roughly 60 MB of memory)
#  Factor Ops : 6.979e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.32324518e+08 -1.30383406e+08  1.39e+02 0.00e+00  3.91e+03     0s
#    1   5.16112772e+07 -4.17271429e+07  4.89e+01 2.27e-13  9.32e+02     0s
#    2   8.37229277e+06 -1.18081021e+07  7.88e+00 3.84e-12  1.64e+02     0s
#    3   8.94895644e+05 -2.08604932e+06  8.30e-01 1.48e-12  2.18e+01     0s
#
# Barrier performed 3 iterations in 0.44 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 19461 iterations and 0.44 seconds (0.44 work units)
# Optimal objective  0.000000000e+00
# 96
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2018.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpgd3evdn_.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x66d02694
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-14, 3e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 93590 rows and 55836 columns
# Presolve time: 0.17s
# Presolved: 64093 rows, 84324 columns, 203192 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.458e+05
#  Factor NZ  : 6.370e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.389e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.27587271e+08 -7.82698731e+07  9.21e+01 0.00e+00  3.24e+03     0s
#    1   5.25096744e+07 -3.49301932e+07  3.18e+01 1.71e-13  8.77e+02     0s
#    2   5.22832435e+06 -7.88595905e+06  3.06e+00 2.27e-13  1.05e+02     0s
#    3   7.65756725e+05 -1.95468147e+06  4.68e-01 1.71e-13  1.98e+01     0s
#    4   3.55511028e+04 -1.77088242e+05  2.11e-02 1.71e-13  1.48e+00     0s
#    5   3.44200220e+01 -3.56429922e+02  1.58e-05 1.71e-13  2.72e-03     0s
#    6   3.45903725e-05 -3.89011976e-04  1.99e-11 2.27e-13  2.94e-09     0s
#
# Barrier performed 6 iterations in 0.47 seconds (0.40 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Solved in 26560 iterations and 0.48 seconds (0.63 work units)
# Optimal objective  0.000000000e+00
# 97
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2019.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp69ma7whb.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xad462eb4
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-14, 3e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 93441 rows and 55689 columns
# Presolve time: 0.17s
# Presolved: 64242 rows, 84471 columns, 203620 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.461e+05
#  Factor NZ  : 6.389e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.401e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.27465980e+08 -7.82554572e+07  9.21e+01 0.00e+00  3.24e+03     0s
#    1   5.25125442e+07 -3.49833645e+07  3.19e+01 1.71e-13  8.76e+02     0s
#    2   5.63810457e+06 -7.55301055e+06  3.32e+00 1.71e-13  1.07e+02     0s
#    3   8.96051516e+05 -1.89575435e+06  5.18e-01 1.71e-13  2.03e+01     0s
#    4   6.85741406e+04 -1.63353573e+05  3.84e-02 1.71e-13  1.62e+00     0s
#    5   1.73799393e+03 -4.06334596e+03  9.64e-04 1.71e-13  4.03e-02     0s
#    6   9.60840282e-03 -9.57872652e-02  5.24e-09 1.71e-13  7.31e-07     0s
#    7   9.60840378e-09 -9.57872817e-08  9.20e-12 2.27e-13  7.31e-13     0s
#
# Barrier performed 7 iterations in 0.48 seconds (0.43 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 24803 iterations and 0.51 seconds (0.53 work units)
# Optimal objective  0.000000000e+00
# 98
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2020.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpvj5ja4pm.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x456d8ac8
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-15, 3e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 93480 rows and 55696 columns
# Presolve time: 0.18s
# Presolved: 64203 rows, 84464 columns, 203532 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.460e+05
#  Factor NZ  : 6.398e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.424e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.27496209e+08 -7.82776798e+07  9.21e+01 0.00e+00  3.24e+03     0s
#    1   5.26682690e+07 -3.48957889e+07  3.20e+01 1.71e-13  8.78e+02     0s
#    2   5.07893879e+06 -7.93932194e+06  2.83e+00 1.71e-13  1.04e+02     0s
#    3   5.40865357e+05 -2.02663829e+06  2.90e-01 1.71e-13  1.84e+01     0s
#    4   2.74993898e+04 -1.07923696e+05  1.37e-02 1.71e-13  9.42e-01     0s
#    5   3.17152478e+00 -6.67855534e+01  8.80e-07 1.71e-13  4.85e-04     0s
#
# Barrier performed 5 iterations in 0.47 seconds (0.39 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 24604 iterations and 0.51 seconds (0.52 work units)
# Optimal objective  0.000000000e+00
# 99
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2021.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpjfhorlns.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xd6a2fa00
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-14, 3e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 93376 rows and 55688 columns
# Presolve time: 0.17s
# Presolved: 64307 rows, 84472 columns, 203756 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.464e+05
#  Factor NZ  : 6.400e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.429e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.27411687e+08 -7.82061833e+07  9.21e+01 0.00e+00  3.23e+03     0s
#    1   5.24697254e+07 -3.50359951e+07  3.19e+01 1.71e-13  8.76e+02     0s
#    2   5.47288726e+06 -7.60593738e+06  3.23e+00 2.27e-13  1.05e+02     0s
#    3   1.21607845e+06 -2.35600155e+06  7.11e-01 1.71e-13  2.63e+01     0s
#    4   6.03165828e+04 -2.84762750e+05  3.32e-02 1.71e-13  2.41e+00     0s
#    5   1.15344820e+03 -1.77158740e+04  4.78e-04 2.27e-13  1.31e-01     0s
#    6   7.92728165e-03 -1.42074104e+00  1.40e-09 2.27e-13  9.90e-06     0s
#    7   2.40787566e-08 -4.31543727e-06  2.81e-12 1.71e-13  3.01e-11     0s
#
# Barrier performed 7 iterations in 0.48 seconds (0.43 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Solved in 27648 iterations and 0.49 seconds (0.67 work units)
# Optimal objective  0.000000000e+00
# 100
# Reading file for Florida: Data/NREL_NSRDB_Florida/1060499_25.77_-80.18_2022.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpo3uyhgr7.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x542b903f
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-14, 3e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 93345 rows and 55695 columns
# Presolve time: 0.17s
# Presolved: 64338 rows, 84465 columns, 203808 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.465e+05
#  Factor NZ  : 6.371e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.359e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.27168690e+08 -7.81648377e+07  9.18e+01 0.00e+00  3.23e+03     0s
#    1   5.23793094e+07 -3.50708007e+07  3.18e+01 1.71e-13  8.74e+02     0s
#    2   5.26071208e+06 -8.06445037e+06  3.08e+00 1.71e-13  1.07e+02     0s
#    3   9.73947968e+05 -1.94253365e+06  5.60e-01 1.71e-13  2.12e+01     0s
#    4   1.63651151e+05 -2.93258810e+05  8.86e-02 1.71e-13  3.20e+00     0s
#    5   7.72142058e+03 -3.01488674e+04  3.98e-03 1.71e-13  2.63e-01     0s
#    6   6.99631689e-01 -5.55926839e+01  5.19e-11 2.27e-13  3.90e-04     0s
#
# Barrier performed 6 iterations in 0.49 seconds (0.41 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Solved in 28232 iterations and 0.49 seconds (0.65 work units)
# Optimal objective  0.000000000e+00
# 121
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2018.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp6b41qzcq.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xac318cf5
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 94900 rows and 55661 columns
# Presolve time: 0.17s
# Presolved: 62783 rows, 84499 columns, 200838 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.404e+05
#  Factor NZ  : 6.493e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.891e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.11811046e+08 -9.21751152e+07  7.64e+01 0.00e+00  2.91e+03     0s
#    1   4.35090201e+07 -2.97282928e+07  2.45e+01 1.71e-13  6.99e+02     0s
#    2   2.93776642e+06 -5.84821299e+06  1.72e+00 3.41e-13  6.81e+01     0s
#    3   4.35816133e+05 -1.41181314e+06  2.64e-01 1.71e-13  1.33e+01     0s
#    4   2.14597212e+03 -9.20305713e+04  6.53e-04 1.71e-13  6.61e-01     0s
#    5   3.09939448e-01 -9.80974656e+00  1.99e-09 1.71e-13  7.10e-05     0s
#
# Barrier performed 5 iterations in 0.45 seconds (0.38 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 19713 iterations and 0.45 seconds (0.42 work units)
# Optimal objective  0.000000000e+00
# 122
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2019.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpa80o1r6e.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x0fb66a01
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-05, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 94991 rows and 55662 columns
# Presolve time: 0.17s
# Presolved: 62692 rows, 84498 columns, 200634 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.400e+05
#  Factor NZ  : 6.575e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.095e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.11665131e+08 -9.22928531e+07  7.60e+01 0.00e+00  2.90e+03     0s
#    1   4.35087699e+07 -2.95723362e+07  2.44e+01 1.71e-13  6.99e+02     0s
#    2   4.67587384e+06 -5.93491736e+06  2.56e+00 3.98e-13  8.43e+01     0s
#    3   6.25141250e+05 -1.33642706e+06  3.40e-01 1.71e-13  1.43e+01     0s
#    4   2.13164585e+03 -6.61515093e+04  3.25e-13 1.71e-13  4.79e-01     0s
#
# Barrier performed 4 iterations in 0.43 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 19990 iterations and 0.45 seconds (0.42 work units)
# Optimal objective  0.000000000e+00
# 123
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2020.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpifzmu3ng.pyomo.lp
# Reading time = 0.29 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xa1a6c2c3
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e-05, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 94881 rows and 55665 columns
# Presolve time: 0.17s
# Presolved: 62802 rows, 84495 columns, 200884 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.405e+05
#  Factor NZ  : 6.522e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.956e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.11783460e+08 -9.20968631e+07  7.64e+01 0.00e+00  2.91e+03     0s
#    1   4.32868859e+07 -2.99445053e+07  2.44e+01 1.71e-13  6.98e+02     0s
#    2   2.81893135e+06 -5.91919161e+06  1.67e+00 3.41e-13  6.74e+01     0s
#    3   1.37258687e+05 -8.37171582e+05  8.22e-02 1.71e-13  6.91e+00     0s
#    4   5.96722235e+02 -6.01592552e+03  5.97e-13 2.27e-13  4.63e-02     0s
#
# Barrier performed 4 iterations in 0.45 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 19210 iterations and 0.45 seconds (0.41 work units)
# Optimal objective  0.000000000e+00
# 124
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2021.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmptf6iv1fp.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xef6b9b22
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-06, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 94852 rows and 55653 columns
# Presolve time: 0.17s
# Presolved: 62831 rows, 84507 columns, 200934 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.406e+05
#  Factor NZ  : 6.520e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.943e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.11153851e+08 -9.19814823e+07  7.59e+01 0.00e+00  2.89e+03     0s
#    1   4.30487878e+07 -2.98110324e+07  2.42e+01 1.71e-13  6.94e+02     0s
#    2   3.08345169e+06 -5.89149988e+06  1.82e+00 3.69e-13  6.96e+01     0s
#    3   1.67123596e+05 -8.41447867e+05  9.30e-02 1.71e-13  7.16e+00     0s
#    4   7.08015642e+02 -4.63481358e+03  4.69e-13 1.71e-13  3.74e-02     0s
#
# Barrier performed 4 iterations in 0.45 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 19567 iterations and 0.45 seconds (0.49 work units)
# Optimal objective  0.000000000e+00
# 125
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2022.csv
# Set parameter Username
#
# --------------------------------------------
# Warning: your license will expire in 13 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmprm9f_6ln.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x88173e94
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-05, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 94650 rows and 55661 columns
# Presolve time: 0.17s
# Presolved: 63033 rows, 84499 columns, 201322 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.414e+05
#  Factor NZ  : 6.500e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.864e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.10675846e+08 -9.16978584e+07  7.57e+01 0.00e+00  2.88e+03     0s
#    1   4.28941549e+07 -2.99590661e+07  2.43e+01 1.71e-13  6.92e+02     0s
#    2   3.17545428e+06 -5.95476996e+06  1.87e+00 4.55e-13  7.07e+01     0s
#    3   5.62866955e+05 -1.07534622e+06  3.23e-01 1.92e-13  1.18e+01     0s
#    4   6.87935349e+04 -9.73469007e+04  3.71e-02 1.71e-13  1.17e+00     0s
#
# Barrier performed 4 iterations in 0.45 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 19519 iterations and 0.45 seconds (0.42 work units)
# Optimal objective  0.000000000e+00

# %%
# Initialize a dictionary to store averaged results
testing_averaged_results = {}

# Iterate over each location
for location, years_data in testing_results.items():
    # Initialize a dictionary to store sums and counts for averaging
    sums = {
        'Total Cost': 0,
        'Capital Cost': 0,
        'Operation Cost': 0
    }
    count = 0

    # Iterate over each year for the location
    for year, data in years_data.items():
        for key in sums:
            sums[key] += data[key]
        count += 1

    # Calculate averages
    testing_averaged_results[location] = {key: value / count for key, value in sums.items()}

# Print the averaged results
print(testing_averaged_results)
# Out:
# {'Arizona': {'Total Cost': 23404.0798, 'Capital Cost': 23186.777, 'Operation Cost': 217.3028}, 'Alaska': {'Total Cost': 46083.736, 'Capital Cost': 46083.736, 'Operation Cost': 0.0}, 'Minnesota': {'Total Cost': 33275.964, 'Capital Cost': 33275.964, 'Operation Cost': 0.0}, 'Florida': {'Total Cost': 20855.406, 'Capital Cost': 20855.406, 'Operation Cost': 0.0}, 'HalfMoonBay': {'Total Cost': 21458.573, 'Capital Cost': 21458.573, 'Operation Cost': 0.0}}

# %%
from pathlib import Path

# Define the output file path
output_file = "Results_SA_Location_RO.xlsx"

# Store Training Result
train_df = pd.DataFrame(training_results).T 
sheet_name_train = "Training Results"

# Check if the file exists
if not Path(output_file).exists():
    # If the file does not exist, create it
    with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
        train_df.to_excel(writer, sheet_name=sheet_name_train)
    print(f"File '{output_file}' created with sheet '{sheet_name_train}'.")
else:
    # If the file exists, append the new sheet
    with pd.ExcelWriter(output_file, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
        train_df.to_excel(writer, sheet_name=sheet_name_train)
    print(f"Data written to '{output_file}' in sheet '{sheet_name_train}'.")


# Store Testing Result
test_df = pd.DataFrame(testing_averaged_results).T 
sheet_name_test = "Testing Results"

# Check if the file exists
if not Path(output_file).exists():
    # If the file does not exist, create it
    with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
        test_df.to_excel(writer, sheet_name=sheet_name_test)
    print(f"File '{output_file}' created with sheet '{sheet_name_test}'.")
else:
    # If the file exists, append the new sheet
    with pd.ExcelWriter(output_file, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
        test_df.to_excel(writer, sheet_name=sheet_name_test)
    print(f"Data written to '{output_file}' in sheet '{sheet_name_test}'.")
# Out:
# File 'Results_SA_Location_RO.xlsx' created with sheet 'Training Results'.
# Data written to 'Results_SA_Location_RO.xlsx' in sheet 'Testing Results'.
