# %%
import Data_Conversion
import Input_Parameters 
import Data_Conversion
import Passive_Model
import Solar_Generation
import Electrical_Load
import SO
# Out:
# /Users/jimmy/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
import numpy as np
import pandas as pd

# %%
# Sensitivity Analysis on Loss of Load Cost, Stochastic Optimization
# Fred Fan, Stanford University, 03/17/2025

# %%
# Define the base data directory, list of loss of load costs, and the weather year.
data_dir = "Data"

location = "HalfMoonBay"

# Example loss of load cost sensitivity
lol_costs = [10, 100, 1000] # $/kWh 

# 20 years of training data
weather_year_list_training = list(range(1998, 2018))  # use list(range(1998, 2018)) for full dataset
# 5 years of training data
weather_year_list_testing = list(range(2018, 2023))  # use list(range(2018, 2023)) for full dataset

# Set a random seed for consistency

total_cells = len(weather_year_list_training) + len(weather_year_list_testing) 

sequential_numbers = np.arange(1, total_cells + 1)

# Reshape the array into a 2D array with i rows and j columns
data = sequential_numbers.reshape(1, total_cells)

# Convert the array into a DataFrame
random_seeds = pd.DataFrame(data, columns=[f'Column_{k+1}' for k in range(total_cells)])

lat, lon, timezone = Data_Conversion.get_timezone_singlezone(data_dir, location)

print(random_seeds)
# Out:
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_1998.csv
#    Column_1  Column_2  Column_3  Column_4  Column_5  Column_6  Column_7  \
# 0         1         2         3         4         5         6         7
#
#    Column_8  Column_9  Column_10  ...  Column_16  Column_17  Column_18  \
# 0         8         9         10  ...         16         17         18
#
#    Column_19  Column_20  Column_21  Column_22  Column_23  Column_24  Column_25
# 0         19         20         21         22         23         24         25
#
# [1 rows x 25 columns]

# %%
# Create the dictionary
training_results = {}

# %%
# Sensitivity Analysis on Loss of Load Cost

# Initialize storing space to store all input_dfs
input_df_list_train = []

# First, collect all training data
for j in range(len(weather_year_list_training)):
    year = weather_year_list_training[j]

    # Get a unique random seed number
    random_seed = random_seeds.iloc[0, j]
    print(random_seed)
    
    # Read NSRDB weather data of the given location of the given year
    NSRDB_raw_weather = Data_Conversion.read_NSRDB(data_dir, location, year)

    # Prepare weather data file using NSRDB data
    weather_data = Data_Conversion.prepare_NSRDB(NSRDB_raw_weather, lat, lon, timezone)

    # Prepare heating and cooling load using weather data and passive model
    NetHeatTransfers = Passive_Model.passive_model(Input_Parameters.calibration_file_path, weather_data, Input_Parameters.T_indoor_constant, lat)

    # Prepare solar PV capacity factor using weather data
    pv_cf = Solar_Generation.generate_pv(weather_data, lat)

    # Prepare occupancy and electrical load schedule using for a specific random seed number for a specific year at a specific location
    load_sched = Electrical_Load.generate_schedules("bayes", weather_data, random_seed)
    
    # Combine all relative input data as input_df, which will be the input of the capacity optimization algorithm
    input_df = Data_Conversion.combine_input_NSRDB(weather_data, load_sched, pv_cf, NetHeatTransfers)

    # Add input_df to list
    input_df_list_train.append(input_df)

# Now that we have all training data, run sensitivity analysis
training_results = {}  # Initialize results dictionary
for i in range(len(lol_costs)):
    lolc = lol_costs[i]
    print(f"Running optimization with loss of load cost: {lolc}")
    
    PV_Size, Battery_Size, PCM_Heating_Size, PCM_Cooling_Size, ObjValue, First_stage_cost, Second_stage_cost = SO.SO_training(input_df_list_train, lolc)

    # Store the variables in the nested dictionary
    training_results[lolc] = {
        'PV_Size': PV_Size,
        'Battery_Size': Battery_Size,
        'PCM_Heating_Size': PCM_Heating_Size,
        'PCM_Cooling_Size': PCM_Cooling_Size,
        'Total Cost': ObjValue,
        'Capital Cost': First_stage_cost,
        'Operation Cost': Second_stage_cost
    }
# Out:
# 1
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42
#  153   2.01937746e+04  2.01937740e+04  5.75e-09 1.81e-13  1.42e-10   160s
#  154   2.01937743e+04  2.01937743e+04  1.39e-09 1.48e-12  1.13e-11   161s
#  155   2.01937743e+04  2.01937743e+04  4.42e-10 4.31e-11  3.74e-14   162s
#
# Barrier solved model in 155 iterations and 161.62 seconds (238.30 work units)
# Optimal objective 2.01937743e+04
#
# Crossover log...
#
#   397187 DPushes remaining with DInf 0.0000000e+00               163s
#    58722 DPushes remaining with DInf 0.0000000e+00               165s
#        0 DPushes remaining with DInf 0.0000000e+00               168s
#
#   680969 PPushes remaining with PInf 0.0000000e+00               168s
#   317149 PPushes remaining with PInf 0.0000000e+00               170s
#    39687 PPushes remaining with PInf 0.0000000e+00               175s
#      957 PPushes remaining with PInf 0.0000000e+00               180s
#        0 PPushes remaining with PInf 0.0000000e+00               181s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.5206847e-12    181s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   882895    2.0193774e+04   0.000000e+00   0.000000e+00    184s
#
# Solved with barrier
# Solved in 882895 iterations and 185.78 seconds (271.38 work units)
# Optimal objective  2.019377430e+04
# Running optimization with loss of load cost: 100
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp5c_jv3qa.pyomo.lp
# Reading time = 6.65 seconds
# x1: 3153660 rows, 2803205 columns, 8496599 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 3153660 rows, 2803205 columns and 8496599 nonzeros
# Model fingerprint: 0xd43d7214
# Coefficient statistics:
#   Matrix range     [8e-04, 1e+00]
#   Objective range  [5e+00, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e-06, 2e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 945882 rows and 770723 columns (presolve time = 10s) ...
# Presolve removed 1009276 rows and 770723 columns (presolve time = 10s) ...
# Presolve removed 1009276 rows and 770723 columns
# Presolve time: 14.57s
# Presolved: 2144384 rows, 2032482 columns, 8817747 nonzeros
#
# Ordering time: 1.56s
#
# Barrier statistics:
#  Dense cols : 4
#  AA' NZ     : 1.422e+07
#  Factor NZ  : 4.158e+07 (roughly 2.0 GB of memory)
#  Factor Ops : 8.493e+08 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.15198904e+08 -2.47854752e+07  5.18e+02 0.00e+00  5.51e+02    20s
#    1   4.62330697e+07 -3.61174410e+07  1.47e+02 5.88e-01  1.61e+02    20s
#    2   1.75895199e+07 -3.55908550e+07  4.63e+01 2.63e-01  6.38e+01    21s
#    3   8.77803451e+06 -2.68050716e+07  1.61e+01 1.01e-01  2.62e+01    22s
#    4   3.87908126e+06 -1.34170126e+07  4.82e+00 3.41e-02  9.44e+00    23s
#    5   9.61507471e+05 -6.67141885e+06  1.99e+00 1.44e-02  3.99e+00    23s
#    6   5.27279669e+05 -3.24437021e+06  1.11e+00 6.27e-03  1.84e+00    24s
#    7   1.88820847e+05 -9.56578878e+05  1.10e-01 1.72e-03  5.19e-01    25s
#    8   1.68839628e+05 -4.64594806e+05  8.84e-02 8.61e-04  2.74e-01    25s
#    9   1.22189414e+05 -2.69253116e+05  4.18e-02 5.13e-04  1.63e-01    26s
#   10   9.87723159e+04 -1.31362459e+05  2.50e-02 2.77e-04  8.99e-02    27s
#   11   8.19306945e+04 -9.57337430e+04  1.58e-02 2.13e-04  6.71e-02    28s
#   12   7.06227416e+04 -6.74049043e+04  1.08e-02 1.65e-04  5.05e-02    28s
#   13   6.22062112e+04 -4.72329004e+04  7.67e-03 1.30e-04  3.89e-02    29s
#   14   5.44789975e+04 -1.68806982e+04  5.31e-03 7.67e-05  2.41e-02    30s
#   82   2.09482255e+04  2.09482255e+04  5.21e-10 2.01e-11  1.76e-16   104s
#
# Barrier solved model in 82 iterations and 103.95 seconds (158.36 work units)
# Optimal objective 2.09482255e+04
#
# Crossover log...
#
#   386984 DPushes remaining with DInf 0.0000000e+00               105s
#        0 DPushes remaining with DInf 0.0000000e+00               109s
#
#   697150 PPushes remaining with PInf 0.0000000e+00               109s
#   454191 PPushes remaining with PInf 0.0000000e+00               110s
#   106419 PPushes remaining with PInf 0.0000000e+00               116s
#    27650 PPushes remaining with PInf 0.0000000e+00               120s
#     2463 PPushes remaining with PInf 0.0000000e+00               125s
#        0 PPushes remaining with PInf 0.0000000e+00               128s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 4.4729011e-13    128s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   886442    2.0948226e+04   0.000000e+00   0.000000e+00    131s
#
# Solved with barrier
# Solved in 886442 iterations and 132.84 seconds (189.85 work units)
# Optimal objective  2.094822551e+04
# Running optimization with loss of load cost: 1000
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpfetrn4ls.pyomo.lp
# Reading time = 6.55 seconds
# x1: 3153660 rows, 2803205 columns, 8496599 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 3153660 rows, 2803205 columns and 8496599 nonzeros
# Model fingerprint: 0x4acfe6f2
# Coefficient statistics:
#   Matrix range     [8e-04, 1e+00]
#   Objective range  [3e+01, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e-06, 2e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 945882 rows and 770723 columns (presolve time = 8s) ...
# Presolve removed 1009276 rows and 770723 columns
# Presolve time: 12.49s
# Presolved: 2144384 rows, 2032482 columns, 8817747 nonzeros
#
# Ordering time: 2.00s
#
# Barrier statistics:
#  Dense cols : 4
#  AA' NZ     : 1.422e+07
#  Factor NZ  : 4.158e+07 (roughly 2.0 GB of memory)
#  Factor Ops : 8.493e+08 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.15138135e+09 -7.83066585e+07  5.18e+02 0.00e+00  1.95e+03    18s
#    1   3.83700850e+08 -1.10439356e+08  1.46e+02 1.98e+00  5.78e+02    19s
#    2   1.60138963e+08 -1.07924381e+08  5.70e+01 8.37e-01  2.43e+02    20s
#    3   6.68078831e+07 -8.76079435e+07  2.21e+01 3.74e-01  1.09e+02    21s
#    4   2.48892859e+07 -5.46023191e+07  8.59e+00 1.44e-01  4.49e+01    21s
#    5   3.96075117e+06 -2.46481650e+07  2.17e+00 5.08e-02  1.47e+01    22s
#    6   2.55910276e+05 -3.33626531e+06  1.67e-02 5.49e-03  1.66e+00    23s
#    7   1.50915576e+05 -9.47262542e+05  3.38e-03 1.57e-03  4.86e-01    23s
#    8   1.23934398e+05 -5.20429195e+05  1.78e-03 8.65e-04  2.74e-01    24s
#    9   1.03430118e+05 -3.41339100e+05  9.47e-04 5.79e-04  1.83e-01    25s
#   10   8.87645713e+04 -2.23676784e+05  5.78e-04 3.90e-04  1.23e-01    26s
#   11   7.66988516e+04 -1.52207893e+05  3.72e-04 2.77e-04  8.69e-02    26s
#   12   6.64062099e+04 -1.00836166e+05  2.41e-04 1.99e-04  6.11e-02    27s
#   13   5.88052654e+04 -6.36505664e+04  1.63e-04 1.41e-04  4.32e-02    27s
#   14   5.22575624e+04 -2.23386649e+04  1.12e-04 7.69e-05  2.50e-02    28s
#   15   4.49252652e+04 -5.98180190e+03  7.16e-05 4.92e-05  1.63e-02    29s
#   16   3.97756615e+04  4.58607940e+03  5.12e-05 3.12e-05  1.08e-02    30s
#   51   2.14749694e+04  2.14747014e+04  1.21e-08 6.80e-12  7.04e-08    64s
#   52   2.14747899e+04  2.14747292e+04  9.70e-09 4.02e-12  1.59e-08    65s
#   53   2.14747440e+04  2.14747430e+04  3.07e-09 3.07e-12  2.47e-10    66s
#   54   2.14747437e+04  2.14747437e+04  1.15e-09 1.08e-10  2.68e-15    66s
#
# Barrier solved model in 54 iterations and 66.47 seconds (116.19 work units)
# Optimal objective 2.14747437e+04
#
# Crossover log...
#
#   385716 DPushes remaining with DInf 0.0000000e+00                67s
#        0 DPushes remaining with DInf 0.0000000e+00                70s
#
#   699120 PPushes remaining with PInf 0.0000000e+00                70s
#   112324 PPushes remaining with PInf 0.0000000e+00                75s
#    11101 PPushes remaining with PInf 0.0000000e+00                81s
#      709 PPushes remaining with PInf 0.0000000e+00                86s
#        0 PPushes remaining with PInf 0.0000000e+00                87s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.1780335e-03     87s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   886958    2.1474744e+04   0.000000e+00   5.178034e-03     88s
#   886960    2.1474744e+04   0.000000e+00   0.000000e+00     91s
#
# Solved with barrier
# Solved in 886960 iterations and 91.20 seconds (145.59 work units)
# Optimal objective  2.147474366e+04

# %%
print(training_results)
# Out:
# {10: {'PV_Size': 8.018, 'Battery_Size': 2.446, 'PCM_Heating_Size': 38.892, 'PCM_Cooling_Size': 0.0, 'Total Cost': 20193.774, 'Capital Cost': 19821.088, 'Operation Cost': 372.686}, 100: {'PV_Size': 12.156, 'Battery_Size': 4.501, 'PCM_Heating_Size': 49.531, 'PCM_Cooling_Size': 0.0, 'Total Cost': 20948.226, 'Capital Cost': 20646.315, 'Operation Cost': 301.911}, 1000: {'PV_Size': 12.873, 'Battery_Size': 6.8, 'PCM_Heating_Size': 57.322, 'PCM_Cooling_Size': 0.0, 'Total Cost': 21474.744, 'Capital Cost': 21159.902, 'Operation Cost': 314.841}}

# %%
# Testing:

# Create the nested dictionary
testing_results = {lolc: {year: {} for year in weather_year_list_testing} for lolc in lol_costs}

for j in range(len(weather_year_list_testing)):
    
    year = weather_year_list_testing[j]
    
    # Get a unique random seed number
    random_seed = random_seeds.iloc[0, j+len(weather_year_list_training)]
    print(random_seed)
    
    # Read NSRDB weather data of the given location of the given year
    NSRDB_raw_weather = Data_Conversion.read_NSRDB(data_dir, location, year)

    # Prepare weather data file using NSRDB data
    weather_data = Data_Conversion.prepare_NSRDB(NSRDB_raw_weather, lat, lon, timezone)

    # Prepare heating and cooling load using weather data and passive model
    NetHeatTransfers = Passive_Model.passive_model(Input_Parameters.calibration_file_path, weather_data, Input_Parameters.T_indoor_constant, lat)

    # Prepare solar PV capacity factor using weather data
    pv_cf = Solar_Generation.generate_pv(weather_data, lat)

    # Prepare occupancy and electrical load schedule using for a specific random seed number for a specific year at a specific location
    load_sched = Electrical_Load.generate_schedules("bayes", weather_data, random_seed)
    
    # Combine all relative input data as input_df, which will be the input of the capacity optimization algorithm
    input_df = Data_Conversion.combine_input_NSRDB(weather_data, load_sched, pv_cf, NetHeatTransfers)
    
    for i in range(len(lol_costs)):
        
        lolc = lol_costs[i]
        
        test_capacities = [training_results[lolc]['PV_Size'], training_results[lolc]['Battery_Size'], training_results[lolc]['PCM_Heating_Size'], training_results[lolc]['PCM_Cooling_Size']]
        
        ObjValue, First_stage_cost, Second_stage_cost = SO.simulate(input_df, lolc, test_capacities)
        # Store the variables in the nested dictionary
        testing_results[lolc][year] = {
            'Total Cost': ObjValue,
            'Capital Cost': First_stage_cost,
            'Operation Cost': Second_stage_cost
        }
# Out:
# 21
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2018.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpv77_gdlg.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x513b55b2
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-04, 4e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96207 rows and 55661 columns
# Presolve time: 0.16s
# Presolved: 61476 rows, 84499 columns, 198224 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.352e+05
#  Factor NZ  : 6.546e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.252e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.07923074e+06 -7.93092251e+05  7.03e+01 0.00e+00  2.76e+01     0s
#    1   4.16685454e+05 -3.23726037e+05  2.12e+01 4.38e-02  7.37e+00     0s
#    2   5.35147998e+04 -5.45111770e+04  2.22e+00 3.33e-15  8.89e-01     0s
#    3   1.28811379e+04 -1.82364202e+04  5.17e-01 2.44e-15  2.36e-01     0s
#    4   7.19863898e+03 -8.39294481e+03  3.09e-01 1.78e-15  1.16e-01     0s
#    5   4.39261219e+03 -4.37118875e+03  1.90e-01 1.78e-15  6.41e-02     0s
#
# Barrier performed 5 iterations in 0.41 seconds (0.38 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 22514 iterations and 0.42 seconds (0.46 work units)
# Optimal objective  1.182189352e+02
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpk2fv5xp1.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xbdb6be50
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-04, 5e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96190 rows and 55661 columns
# Presolve time: 0.17s
# Presolved: 61493 rows, 84499 columns, 198258 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.352e+05
#  Factor NZ  : 6.540e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.232e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.10268218e+07 -8.58534020e+06  7.35e+01 0.00e+00  2.85e+02     0s
#    1   4.17095483e+06 -2.81652352e+06  2.21e+01 2.13e-14  6.83e+01     0s
#    2   3.65594663e+05 -5.63201573e+05  1.98e+00 4.62e-14  7.46e+00     0s
#    3   8.07140019e+04 -1.38263699e+05  4.34e-01 1.42e-14  1.63e+00     0s
#    4   2.71444980e+04 -4.39892407e+04  1.42e-01 1.42e-14  5.13e-01     0s
#
# Barrier performed 4 iterations in 0.44 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 21025 iterations and 0.44 seconds (0.44 work units)
# Optimal objective  8.759217979e+01
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmptpa83eks.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x118bd966
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-04, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 95292 rows and 55661 columns
# Presolve time: 0.17s
# Presolved: 62391 rows, 84499 columns, 200054 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.388e+05
#  Factor NZ  : 6.469e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.907e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.13050556e+08 -9.06199313e+07  7.70e+01 0.00e+00  2.93e+03     0s
#    1   4.43073192e+07 -2.96480793e+07  2.47e+01 1.99e-13  7.12e+02     0s
#    2   3.04167555e+06 -5.88799602e+06  1.76e+00 3.69e-13  6.99e+01     0s
#    3   6.06116603e+05 -1.37532201e+06  3.55e-01 2.27e-13  1.45e+01     0s
#    4   6.43726839e+04 -1.50193724e+05  3.43e-02 1.71e-13  1.51e+00     0s
#
# Barrier performed 4 iterations in 0.39 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20320 iterations and 0.42 seconds (0.44 work units)
# Optimal objective  0.000000000e+00
# 22
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2019.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpuqotst3t.pyomo.lp
# Reading time = 0.29 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xbb46611a
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-04, 4e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96224 rows and 55662 columns
# Presolve time: 0.19s
# Presolved: 61459 rows, 84498 columns, 198168 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.351e+05
#  Factor NZ  : 6.556e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.278e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.07657896e+06 -7.93721199e+05  6.99e+01 0.00e+00  2.75e+01     0s
#    1   4.11190888e+05 -3.21286836e+05  2.07e+01 4.37e-02  7.27e+00     0s
#    2   6.36435866e+04 -4.99159510e+04  2.74e+00 3.26e-04  9.56e-01     0s
#    3   1.89920413e+04 -1.89686187e+04  7.98e-01 1.78e-15  2.95e-01     0s
#    4   9.01605993e+03 -6.57485710e+03  4.00e-01 1.78e-15  1.18e-01     1s
#    5   6.12315183e+03 -3.46347745e+03  2.73e-01 1.78e-15  7.12e-02     1s
#
# Barrier performed 5 iterations in 0.59 seconds (0.38 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 24002 iterations and 0.59 seconds (0.50 work units)
# Optimal objective  3.457174319e+02
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpkkh1gogp.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xf259361b
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-04, 5e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96208 rows and 55662 columns
# Presolve time: 0.18s
# Presolved: 61475 rows, 84498 columns, 198200 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.351e+05
#  Factor NZ  : 6.553e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.265e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.10034657e+07 -8.59248881e+06  7.31e+01 0.00e+00  2.84e+02     0s
#    1   4.16512415e+06 -2.79635131e+06  2.20e+01 2.13e-14  6.81e+01     0s
#    2   5.37039669e+05 -5.13165990e+05  2.69e+00 4.26e-14  8.62e+00     0s
#    3   9.96417201e+04 -1.35104324e+05  4.93e-01 2.13e-14  1.76e+00     0s
#    4   2.84205530e+04 -2.66263498e+04  1.38e-01 2.13e-14  3.97e-01     0s
#
# Barrier performed 4 iterations in 0.47 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 21363 iterations and 0.49 seconds (0.44 work units)
# Optimal objective  5.248370138e+00
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpdp4muhn5.pyomo.lp
# Reading time = 0.30 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xe4b06255
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-04, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 95365 rows and 55662 columns
# Presolve time: 0.18s
# Presolved: 62318 rows, 84498 columns, 199886 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.385e+05
#  Factor NZ  : 6.481e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.954e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.13037228e+08 -9.07324657e+07  7.69e+01 0.00e+00  2.93e+03     0s
#    1   4.44194574e+07 -2.94572458e+07  2.47e+01 1.71e-13  7.12e+02     0s
#    2   4.53887627e+06 -5.34103073e+06  2.52e+00 3.41e-13  7.94e+01     0s
#    3   5.58783414e+05 -1.37165295e+06  3.08e-01 1.71e-13  1.41e+01     0s
#    4   4.70529872e+03 -9.18629932e+04  1.74e-03 1.71e-13  6.79e-01     0s
#
# Barrier performed 4 iterations in 0.46 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20601 iterations and 0.46 seconds (0.44 work units)
# Optimal objective  0.000000000e+00
# 23
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2020.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpezvlyeq_.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xd8cf388b
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-04, 4e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96203 rows and 55665 columns
# Presolve time: 0.16s
# Presolved: 61480 rows, 84495 columns, 198240 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.352e+05
#  Factor NZ  : 6.545e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.247e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.07693480e+06 -7.92941039e+05  7.01e+01 0.00e+00  2.75e+01     0s
#    1   4.08820661e+05 -3.23609540e+05  2.07e+01 4.38e-02  7.26e+00     0s
#    2   4.94379647e+04 -5.44781084e+04  2.03e+00 3.11e-15  8.48e-01     0s
#    3   1.09203900e+04 -1.61652787e+04  4.38e-01 1.78e-15  2.04e-01     0s
#
# Barrier performed 3 iterations in 0.41 seconds (0.33 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 21815 iterations and 0.41 seconds (0.43 work units)
# Optimal objective  4.105521899e+01
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpr_u4dh3z.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x9d3f7775
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-04, 5e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96185 rows and 55665 columns
# Presolve time: 0.17s
# Presolved: 61498 rows, 84495 columns, 198276 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.353e+05
#  Factor NZ  : 6.537e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.222e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.10167689e+07 -8.58152790e+06  7.34e+01 0.00e+00  2.84e+02     0s
#    1   4.14185098e+06 -2.82890840e+06  2.20e+01 2.13e-14  6.80e+01     0s
#    2   3.58595644e+05 -5.72759955e+05  1.89e+00 3.20e-14  7.43e+00     0s
#    3   2.86640071e+04 -8.38528749e+04  1.45e-01 2.13e-14  8.15e-01     0s
#    4   3.34270529e+02 -3.25099795e+03  1.56e-03 2.13e-14  2.54e-02     0s
#
# Barrier performed 4 iterations in 0.42 seconds (0.37 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20376 iterations and 0.45 seconds (0.42 work units)
# Optimal objective  0.000000000e+00
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp9dp9qj6q.pyomo.lp
# Reading time = 0.29 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x81628cac
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-04, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 95267 rows and 55665 columns
# Presolve time: 0.18s
# Presolved: 62416 rows, 84495 columns, 200112 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.389e+05
#  Factor NZ  : 6.483e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.941e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.13121505e+08 -9.05722127e+07  7.72e+01 0.00e+00  2.93e+03     0s
#    1   4.42061263e+07 -2.98345118e+07  2.47e+01 2.27e-13  7.12e+02     0s
#    2   3.01233027e+06 -5.95406395e+06  1.76e+00 3.41e-13  7.00e+01     0s
#    3   1.55772425e+05 -8.18102159e+05  8.66e-02 2.27e-13  6.93e+00     0s
#    4   6.69258944e+02 -5.10373431e+03  3.21e-05 1.71e-13  4.06e-02     0s
#
# Barrier performed 4 iterations in 0.46 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 19669 iterations and 0.46 seconds (0.42 work units)
# Optimal objective  0.000000000e+00
# 24
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2021.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpzi5lofqb.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xb3d5f1e2
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-06, 4e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96203 rows and 55653 columns
# Presolve time: 0.17s
# Presolved: 61480 rows, 84507 columns, 198232 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.352e+05
#  Factor NZ  : 6.548e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.255e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.07312606e+06 -7.92192604e+05  6.98e+01 0.00e+00  2.74e+01     0s
#    1   4.08742810e+05 -3.24467355e+05  2.07e+01 4.51e-02  7.27e+00     0s
#    2   5.08195275e+04 -5.22192896e+04  2.10e+00 2.66e-15  8.45e-01     0s
#    3   1.36584370e+04 -1.51204335e+04  5.55e-01 1.78e-15  2.19e-01     0s
#    4   8.14810564e+03 -5.25956973e+03  3.53e-01 1.78e-15  1.00e-01     0s
#    5   6.26698637e+03 -4.16908548e+03  2.75e-01 1.78e-15  7.72e-02     0s
#    6   4.10378913e+03 -1.78061021e+03  1.83e-01 3.00e-15  4.29e-02     0s
#
# Barrier performed 6 iterations in 0.49 seconds (0.40 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 22541 iterations and 0.49 seconds (0.52 work units)
# Optimal objective  1.389193060e+02
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmp2_xtpjmh.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x7ce99c99
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-06, 5e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96160 rows and 55653 columns
# Presolve time: 0.17s
# Presolved: 61523 rows, 84507 columns, 198318 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.353e+05
#  Factor NZ  : 6.530e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.202e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.09522831e+07 -8.57085703e+06  7.29e+01 0.00e+00  2.83e+02     0s
#    1   4.14323324e+06 -2.81803311e+06  2.20e+01 2.13e-14  6.80e+01     0s
#    2   3.78816010e+05 -5.63715787e+05  2.06e+00 2.84e-14  7.57e+00     0s
#    3   5.97294913e+04 -1.11260304e+05  3.19e-01 2.13e-14  1.26e+00     0s
#    4   1.93507209e+04 -2.06259027e+04  1.02e-01 2.13e-14  2.87e-01     0s
#    5   8.18090190e+03 -1.08700166e+04  4.41e-02 1.42e-14  1.36e-01     0s
#
# Barrier performed 5 iterations in 0.45 seconds (0.38 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20729 iterations and 0.46 seconds (0.50 work units)
# Optimal objective  2.241328085e+01
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpc26oqgn8.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x3b537ca6
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-06, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 95223 rows and 55653 columns
# Presolve time: 0.18s
# Presolved: 62460 rows, 84507 columns, 200192 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.391e+05
#  Factor NZ  : 6.463e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.896e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.12459311e+08 -9.04440667e+07  7.66e+01 0.00e+00  2.92e+03     0s
#    1   4.39731531e+07 -2.96941770e+07  2.46e+01 1.71e-13  7.08e+02     0s
#    2   3.39388623e+06 -5.42238561e+06  1.96e+00 2.84e-13  6.95e+01     0s
#    3   2.58008656e+05 -1.04154415e+06  1.50e-01 1.71e-13  9.32e+00     0s
#    4   1.11586469e+03 -1.72390877e+04  4.26e-13 2.27e-13  1.29e-01     0s
#
# Barrier performed 4 iterations in 0.44 seconds (0.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20008 iterations and 0.44 seconds (0.50 work units)
# Optimal objective  0.000000000e+00
# 25
# Reading file for HalfMoonBay: Data/NREL_NSRDB_HalfMoonBay/137344_37.49_-122.42_2022.csv
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpe98uxinz.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0x1740749d
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-04, 4e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96219 rows and 55661 columns
# Presolve time: 0.17s
# Presolved: 61464 rows, 84499 columns, 198184 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.351e+05
#  Factor NZ  : 6.548e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.258e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.07110127e+06 -7.91731587e+05  6.97e+01 0.00e+00  2.74e+01     0s
#    1   4.10016372e+05 -3.24490637e+05  2.09e+01 4.48e-02  7.28e+00     0s
#    2   4.92678063e+04 -5.37646241e+04  2.03e+00 3.55e-15  8.40e-01     0s
#    3   1.45030054e+04 -1.68368910e+04  5.88e-01 2.00e-15  2.39e-01     0s
#    4   1.00984046e+04 -6.46080470e+03  4.20e-01 1.78e-15  1.24e-01     0s
#    5   6.14407531e+03 -3.51629711e+03  2.61e-01 1.78e-15  7.13e-02     0s
#
# Barrier performed 5 iterations in 0.45 seconds (0.38 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 22412 iterations and 0.46 seconds (0.45 work units)
# Optimal objective  2.763998628e+02
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpmywvoogw.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xd5c38dd1
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-04, 5e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 96180 rows and 55661 columns
# Presolve time: 0.18s
# Presolved: 61503 rows, 84499 columns, 198262 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.352e+05
#  Factor NZ  : 6.534e+05 (roughly 60 MB of memory)
#  Factor Ops : 8.213e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.09320423e+07 -8.56208745e+06  7.28e+01 0.00e+00  2.82e+02     0s
#    1   4.14911238e+06 -2.82443812e+06  2.21e+01 2.13e-14  6.80e+01     0s
#    2   3.52090596e+05 -5.70802702e+05  1.92e+00 3.91e-14  7.36e+00     0s
#    3   8.55288106e+04 -1.01419055e+05  4.62e-01 2.13e-14  1.39e+00     0s
#
# Barrier performed 3 iterations in 0.43 seconds (0.34 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20708 iterations and 0.46 seconds (0.43 work units)
# Optimal objective  6.723626490e+02
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-15
# Read LP format model from file /var/folders/ll/cq_mlqg56938kmwh8dys19n80000gn/T/tmpxk9030o4.pyomo.lp
# Reading time = 0.28 seconds
# x1: 157683 rows, 140160 columns, 385434 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[arm])
# Thread count: 11 physical cores, 11 logical processors, using up to 11 threads
# Optimize a model with 157683 rows, 140160 columns and 385434 nonzeros
# Model fingerprint: 0xb812e698
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+03, 1e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-04, 6e+01]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 95096 rows and 55661 columns
# Presolve time: 0.17s
# Presolved: 62587 rows, 84499 columns, 200430 nonzeros
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.396e+05
#  Factor NZ  : 6.457e+05 (roughly 60 MB of memory)
#  Factor Ops : 7.858e+06 (less than 1 second per iteration)
#  Threads    : 9
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.12162064e+08 -9.02536328e+07  7.65e+01 0.00e+00  2.91e+03     0s
#    1   4.39205514e+07 -2.97758592e+07  2.47e+01 1.71e-13  7.07e+02     0s
#    2   3.31747289e+06 -5.46903342e+06  1.92e+00 3.13e-13  6.89e+01     0s
#    3   7.72621360e+05 -1.17317694e+06  4.45e-01 1.71e-13  1.42e+01     0s
#    4   2.86132510e+05 -1.90427851e+05  1.62e-01 1.71e-13  3.39e+00     0s
#
# Barrier performed 4 iterations in 0.42 seconds (0.37 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 20234 iterations and 0.45 seconds (0.44 work units)
# Optimal objective  2.890907981e+03

# %%
# Initialize a dictionary to store averaged results
testing_averaged_results = {}

# Iterate over each loss of load cost
for lolc, years_data in testing_results.items():
    # Initialize a dictionary to store sums and counts for averaging
    sums = {
        'Total Cost': 0,
        'Capital Cost': 0,
        'Operation Cost': 0
    }
    count = 0

    # Iterate over each year for the loss of load cost
    for year, data in years_data.items():
        for key in sums:
            sums[key] += data[key]
        count += 1

    # Calculate averages
    testing_averaged_results[lolc] = {key: value / count for key, value in sums.items()}

# Print the averaged results
print(testing_averaged_results)
# Out:
# {10: {'Total Cost': 20005.0986, 'Capital Cost': 19821.037, 'Operation Cost': 184.06199999999998}, 100: {'Total Cost': 20803.8488, 'Capital Cost': 20646.325, 'Operation Cost': 157.52320000000003}, 1000: {'Total Cost': 21738.1246, 'Capital Cost': 21159.943, 'Operation Cost': 578.1816}}

# %%
from pathlib import Path

# Define the output file path
output_file = "Results_SA_LoLC_SO.xlsx"

# Store Training Result
train_df = pd.DataFrame(training_results).T 
sheet_name_train = "Training Results"

# Check if the file exists
if not Path(output_file).exists():
    # If the file does not exist, create it
    with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
        train_df.to_excel(writer, sheet_name=sheet_name_train)
    print(f"File '{output_file}' created with sheet '{sheet_name_train}'.")
else:
    # If the file exists, append the new sheet
    with pd.ExcelWriter(output_file, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
        train_df.to_excel(writer, sheet_name=sheet_name_train)
    print(f"Data written to '{output_file}' in sheet '{sheet_name_train}'.")


# Store Testing Result
test_df = pd.DataFrame(testing_averaged_results).T 
sheet_name_test = "Testing Results"

# Check if the file exists
if not Path(output_file).exists():
    # If the file does not exist, create it
    with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
        test_df.to_excel(writer, sheet_name=sheet_name_test)
    print(f"File '{output_file}' created with sheet '{sheet_name_test}'.")
else:
    # If the file exists, append the new sheet
    with pd.ExcelWriter(output_file, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
        test_df.to_excel(writer, sheet_name=sheet_name_test)
    print(f"Data written to '{output_file}' in sheet '{sheet_name_test}'.")
# Out:
# File 'Results_SA_LoLC_SO.xlsx' created with sheet 'Training Results'.
# Data written to 'Results_SA_LoLC_SO.xlsx' in sheet 'Testing Results'.
